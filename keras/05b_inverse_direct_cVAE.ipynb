# %% [markdown]
# # Direct inverse design: conditional variational autoencoder
#
# ## Import modules

# %%
import pickle
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

import helper

# Dynamic GPU memory allocation: For local prototyping, don't block GPU
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)
# Out:
# 2023-07-03 13:46:54.865819: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-03 13:46:55.445082: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-03 13:46:56.454424: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:56.472428: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:56.472613: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:56.971485: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:56.971662: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:56.971786: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:56.971891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10867 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:21:00.0, compute capability: 8.9

# %% [markdown]
# ## load the training data

# %%
data_path = 'datasets/dataset1_random.h5'

# load data and scalers
x_train, x_test, y_train, y_test = helper.load_reflection_spectra_data(
    data_path)
scaler_mat, scaler_thick = pickle.load(
    open('{}_scalers.pkl'.format(os.path.splitext(data_path)[0]), 'rb'))

# %% [markdown]
# ### cVAE resnet model
#
# *Note*, instead of `MaxPooling`, we here use `strides=2` to reduce the output dimension of a convolution by a factor of 2. In the up-sampling case (see forward model), strides can also be used with transpose convolutions to increase the output dimension. However the latter often leads to artifacts in the upsampled outputs, therefore for a robust first try dedicated `UpSampling` layers are preferred.
#
# In the down-sampling case, strides usually don't induce artifacts and are computationally cheaper as well as are more flexible (they are trainable), in contrast to `MaxPooling`.
#
# First we define a helpers to generate sequences of `N_block` residual blocks:

# %%
def resblock_sequence_down(x_in, N_filter, N_blocks):
    x = x_in
    for i in range(N_blocks):
        x = helper.residual_block(x, N_filter, kernel_size=3, strides=1, with_BN=True)
    # down: use strides=2 for downsampling (more flexible, since trainable).
    x = helper.residual_block(x, N_filter, kernel_size=3, strides=2)
    return x


def resblock_sequence_up(x_in, N_filter, N_blocks):
    x = x_in
    for i in range(N_blocks):
        x = helper.residual_block(x, N_filter, kernel_size=3, strides=1, with_BN=True)
    # up: use upsampling (more robust than transpose convolutions with stride 2)
    x = keras.layers.UpSampling1D()(x)
    return x


def resblock_sequence_id(x_in, N_filter, N_blocks):
    # identity block sequence: input shape = output shape
    x = x_in
    for i in range(N_blocks):
        x = helper.residual_block(x, N_filter, kernel_size=3, strides=1, with_BN=True)
    return x

# %% [markdown]
# ## RNG sampling layer for regularization
#
# The latent space of a VAE is regularized via random sampling from a normal distribution during training and ragularization of these distributions using a KL loss. The KL loss will be introduced below.
# Here we define a sampling layer that generates randomly perturbed latent vectors:

# %%
class SamplingRNG(keras.layers.Layer):
    """layer to sample a normal distributed random numbers z with mean `z_mean` and logarithmic variance `z_log_var`"""

    def call(self, inputs):
        z_mean, z_var_log = inputs
        epsilon = keras.backend.random_normal(shape=tf.shape(z_mean)[1:])
        z = z_mean + keras.backend.exp(0.5 * z_var_log) * epsilon
        return z

# %% [markdown]
# ## define the encoder
#
# The cVAE consists of first an encoder. This compresses the condition (target spectrum) and the geometry (design) into a latent space.

# %%
keras.backend.clear_session()

# some config for the cVAE
latent_dim = 2   # for interpretability
N_blocks = 4     # Nr of resblocks between upsamplings


# input layers
condition_target_spec_input = keras.layers.Input(
    shape=y_train.shape[1:], name='condition_in')
design_in = keras.Input(shape=x_train.shape[1:], name='design_in')

# spectrum path
x = condition_target_spec_input
x = resblock_sequence_down(x, N_filter=32, N_blocks=N_blocks)   # 64 --> 32
x = resblock_sequence_down(x, N_filter=64, N_blocks=N_blocks)   # 32 --> 16
x = resblock_sequence_down(x, N_filter=128, N_blocks=N_blocks)  # 16 --> 8
x = resblock_sequence_down(x, N_filter=256, N_blocks=N_blocks)  # 8 --> 4
x_spec = keras.layers.Flatten()(x)

# geometry path
x = design_in
x = resblock_sequence_id(x, N_filter=128, N_blocks=N_blocks)    # 5 --> 2
x_design = keras.layers.Flatten()(x)

# merge both paths
x = keras.layers.Concatenate()([x_spec, x_design])
x = keras.layers.Dense(256)(x)
x = keras.layers.LeakyReLU(alpha=1e-1)(x)

# output: latent sampling
z_mean = keras.layers.Dense(latent_dim)(x)
z_var_log = keras.layers.Dense(latent_dim)(x)
z = SamplingRNG()([z_mean, z_var_log])


encoder = keras.Model([design_in, condition_target_spec_input], [
                      z_mean, z_var_log, z], name="encoder")
encoder.summary()
# Out:
# 2023-07-03 13:46:57.166636: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:57.168523: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:57.236391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:57.236916: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:57.237042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:57.237160: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:57.237315: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:57.237432: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-03 13:46:57.237520: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10867 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:21:00.0, compute capability: 8.9
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  condition_in (InputLayer)      [(None, 64, 1)]      0           []
#
#  conv1d_1 (Conv1D)              (None, 64, 32)       32          ['condition_in[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 32)      128         ['conv1d_1[0][0]']
#  alization)
#
#  leaky_re_lu (LeakyReLU)        (None, 64, 32)       0           ['batch_normalization[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 64, 32)       3072        ['leaky_re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 32)      128         ['conv1d_2[0][0]']
#  rmalization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 64, 32)       0           ['batch_normalization_1[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 64, 32)       1024        ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 32)      128         ['conv1d_3[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 64, 32)       64          ['condition_in[0][0]']
#
#  add (Add)                      (None, 64, 32)       0           ['batch_normalization_2[0][0]',
#                                                                   'conv1d[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 64, 32)       0           ['add[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 64, 32)       1024        ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 32)      128         ['conv1d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 64, 32)       0           ['batch_normalization_3[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 64, 32)       3072        ['leaky_re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 32)      128         ['conv1d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 64, 32)       0           ['batch_normalization_4[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 64, 32)       1024        ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 32)      128         ['conv1d_6[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 64, 32)       0           ['batch_normalization_5[0][0]',
#                                                                   'leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 64, 32)       0           ['add_1[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 64, 32)       1024        ['leaky_re_lu_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 32)      128         ['conv1d_7[0][0]']
#  rmalization)
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 64, 32)       0           ['batch_normalization_6[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 64, 32)       3072        ['leaky_re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 32)      128         ['conv1d_8[0][0]']
#  rmalization)
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64, 32)       0           ['batch_normalization_7[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 64, 32)       1024        ['leaky_re_lu_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 32)      128         ['conv1d_9[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 64, 32)       0           ['batch_normalization_8[0][0]',
#                                                                   'leaky_re_lu_5[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64, 32)       0           ['add_2[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 32)      128         ['conv1d_10[0][0]']
#  rmalization)
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 64, 32)       0           ['batch_normalization_9[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 64, 32)       3072        ['leaky_re_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 32)      128         ['conv1d_11[0][0]']
#  ormalization)
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_10[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 32)      128         ['conv1d_12[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 64, 32)       0           ['batch_normalization_11[0][0]',
#                                                                   'leaky_re_lu_8[0][0]']
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 64, 32)       0           ['add_3[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 64, 32)       1056        ['leaky_re_lu_11[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 64, 32)       0           ['conv1d_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 32, 32)       3104        ['leaky_re_lu_12[0][0]']
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 32, 32)       0           ['conv1d_15[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 32, 32)       1056        ['leaky_re_lu_13[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 32, 32)       1056        ['leaky_re_lu_11[0][0]']
#
#  add_4 (Add)                    (None, 32, 32)       0           ['conv1d_16[0][0]',
#                                                                   'conv1d_13[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 32, 32)       0           ['add_4[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 32, 64)       2048        ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 64)      256         ['conv1d_18[0][0]']
#  ormalization)
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_12[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 32, 64)       12288       ['leaky_re_lu_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 64)      256         ['conv1d_19[0][0]']
#  ormalization)
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_13[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 32, 64)       4096        ['leaky_re_lu_16[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 64)      256         ['conv1d_20[0][0]']
#  ormalization)
#
#  conv1d_17 (Conv1D)             (None, 32, 64)       2112        ['leaky_re_lu_14[0][0]']
#
#  add_5 (Add)                    (None, 32, 64)       0           ['batch_normalization_14[0][0]',
#                                                                   'conv1d_17[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 32, 64)       0           ['add_5[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 32, 64)       4096        ['leaky_re_lu_17[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 64)      256         ['conv1d_21[0][0]']
#  ormalization)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_15[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 32, 64)       12288       ['leaky_re_lu_18[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 64)      256         ['conv1d_22[0][0]']
#  ormalization)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_16[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 32, 64)       4096        ['leaky_re_lu_19[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 64)      256         ['conv1d_23[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 32, 64)       0           ['batch_normalization_17[0][0]',
#                                                                   'leaky_re_lu_17[0][0]']
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 32, 64)       0           ['add_6[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 32, 64)       4096        ['leaky_re_lu_20[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 64)      256         ['conv1d_24[0][0]']
#  ormalization)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_18[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 32, 64)       12288       ['leaky_re_lu_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 64)      256         ['conv1d_25[0][0]']
#  ormalization)
#
#  leaky_re_lu_22 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_19[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 32, 64)       4096        ['leaky_re_lu_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 64)      256         ['conv1d_26[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 32, 64)       0           ['batch_normalization_20[0][0]',
#                                                                   'leaky_re_lu_20[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 32, 64)       0           ['add_7[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 32, 64)       4096        ['leaky_re_lu_23[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 64)      256         ['conv1d_27[0][0]']
#  ormalization)
#
#  leaky_re_lu_24 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_21[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 32, 64)       12288       ['leaky_re_lu_24[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 64)      256         ['conv1d_28[0][0]']
#  ormalization)
#
#  leaky_re_lu_25 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_22[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 32, 64)       4096        ['leaky_re_lu_25[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 64)      256         ['conv1d_29[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 32, 64)       0           ['batch_normalization_23[0][0]',
#                                                                   'leaky_re_lu_23[0][0]']
#
#  leaky_re_lu_26 (LeakyReLU)     (None, 32, 64)       0           ['add_8[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_26[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_31[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 16, 64)       12352       ['leaky_re_lu_27[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)     (None, 16, 64)       0           ['conv1d_32[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 16, 64)       4160        ['leaky_re_lu_28[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 16, 64)       4160        ['leaky_re_lu_26[0][0]']
#
#  add_9 (Add)                    (None, 16, 64)       0           ['conv1d_33[0][0]',
#                                                                   'conv1d_30[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)     (None, 16, 64)       0           ['add_9[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 16, 128)      8192        ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 128)     512         ['conv1d_35[0][0]']
#  ormalization)
#
#  leaky_re_lu_30 (LeakyReLU)     (None, 16, 128)      0           ['batch_normalization_24[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 16, 128)      49152       ['leaky_re_lu_30[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 128)     512         ['conv1d_36[0][0]']
#  ormalization)
#
#  leaky_re_lu_31 (LeakyReLU)     (None, 16, 128)      0           ['batch_normalization_25[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 16, 128)      16384       ['leaky_re_lu_31[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 128)     512         ['conv1d_37[0][0]']
#  ormalization)
#
#  conv1d_34 (Conv1D)             (None, 16, 128)      8320        ['leaky_re_lu_29[0][0]']
#
#  add_10 (Add)                   (None, 16, 128)      0           ['batch_normalization_26[0][0]',
#                                                                   'conv1d_34[0][0]']
#
#  leaky_re_lu_32 (LeakyReLU)     (None, 16, 128)      0           ['add_10[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 16, 128)      16384       ['leaky_re_lu_32[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 128)     512         ['conv1d_38[0][0]']
#  ormalization)
#
#  leaky_re_lu_33 (LeakyReLU)     (None, 16, 128)      0           ['batch_normalization_27[0][0]']
#
#  conv1d_39 (Conv1D)             (None, 16, 128)      49152       ['leaky_re_lu_33[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 128)     512         ['conv1d_39[0][0]']
#  ormalization)
#
#  leaky_re_lu_34 (LeakyReLU)     (None, 16, 128)      0           ['batch_normalization_28[0][0]']
#
#  conv1d_40 (Conv1D)             (None, 16, 128)      16384       ['leaky_re_lu_34[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 128)     512         ['conv1d_40[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 16, 128)      0           ['batch_normalization_29[0][0]',
#                                                                   'leaky_re_lu_32[0][0]']
#
#  leaky_re_lu_35 (LeakyReLU)     (None, 16, 128)      0           ['add_11[0][0]']
#
#  conv1d_41 (Conv1D)             (None, 16, 128)      16384       ['leaky_re_lu_35[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 16, 128)     512         ['conv1d_41[0][0]']
#  ormalization)
#
#  leaky_re_lu_36 (LeakyReLU)     (None, 16, 128)      0           ['batch_normalization_30[0][0]']
#
#  conv1d_42 (Conv1D)             (None, 16, 128)      49152       ['leaky_re_lu_36[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 16, 128)     512         ['conv1d_42[0][0]']
#  ormalization)
#
#  leaky_re_lu_37 (LeakyReLU)     (None, 16, 128)      0           ['batch_normalization_31[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 16, 128)      16384       ['leaky_re_lu_37[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 128)     512         ['conv1d_43[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 16, 128)      0           ['batch_normalization_32[0][0]',
#                                                                   'leaky_re_lu_35[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)     (None, 16, 128)      0           ['add_12[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 16, 128)      16384       ['leaky_re_lu_38[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 16, 128)     512         ['conv1d_44[0][0]']
#  ormalization)
#
#  leaky_re_lu_39 (LeakyReLU)     (None, 16, 128)      0           ['batch_normalization_33[0][0]']
#
#  conv1d_45 (Conv1D)             (None, 16, 128)      49152       ['leaky_re_lu_39[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 16, 128)     512         ['conv1d_45[0][0]']
#  ormalization)
#
#  leaky_re_lu_40 (LeakyReLU)     (None, 16, 128)      0           ['batch_normalization_34[0][0]']
#
#  conv1d_46 (Conv1D)             (None, 16, 128)      16384       ['leaky_re_lu_40[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 16, 128)     512         ['conv1d_46[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 16, 128)      0           ['batch_normalization_35[0][0]',
#                                                                   'leaky_re_lu_38[0][0]']
#
#  leaky_re_lu_41 (LeakyReLU)     (None, 16, 128)      0           ['add_13[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_41[0][0]']
#
#  leaky_re_lu_42 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_48[0][0]']
#
#  conv1d_49 (Conv1D)             (None, 8, 128)       49280       ['leaky_re_lu_42[0][0]']
#
#  leaky_re_lu_43 (LeakyReLU)     (None, 8, 128)       0           ['conv1d_49[0][0]']
#
#  conv1d_50 (Conv1D)             (None, 8, 128)       16512       ['leaky_re_lu_43[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 8, 128)       16512       ['leaky_re_lu_41[0][0]']
#
#  add_14 (Add)                   (None, 8, 128)       0           ['conv1d_50[0][0]',
#                                                                   'conv1d_47[0][0]']
#
#  leaky_re_lu_44 (LeakyReLU)     (None, 8, 128)       0           ['add_14[0][0]']
#
#  conv1d_52 (Conv1D)             (None, 8, 256)       32768       ['leaky_re_lu_44[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 256)      1024        ['conv1d_52[0][0]']
#  ormalization)
#
#  leaky_re_lu_45 (LeakyReLU)     (None, 8, 256)       0           ['batch_normalization_36[0][0]']
#
#  conv1d_53 (Conv1D)             (None, 8, 256)       196608      ['leaky_re_lu_45[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 256)      1024        ['conv1d_53[0][0]']
#  ormalization)
#
#  leaky_re_lu_46 (LeakyReLU)     (None, 8, 256)       0           ['batch_normalization_37[0][0]']
#
#  conv1d_54 (Conv1D)             (None, 8, 256)       65536       ['leaky_re_lu_46[0][0]']
#
#  design_in (InputLayer)         [(None, 5, 2)]       0           []
#
#  batch_normalization_38 (BatchN  (None, 8, 256)      1024        ['conv1d_54[0][0]']
#  ormalization)
#
#  conv1d_51 (Conv1D)             (None, 8, 256)       33024       ['leaky_re_lu_44[0][0]']
#
#  conv1d_69 (Conv1D)             (None, 5, 128)       256         ['design_in[0][0]']
#
#  add_15 (Add)                   (None, 8, 256)       0           ['batch_normalization_38[0][0]',
#                                                                   'conv1d_51[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 5, 128)      512         ['conv1d_69[0][0]']
#  ormalization)
#
#  leaky_re_lu_47 (LeakyReLU)     (None, 8, 256)       0           ['add_15[0][0]']
#
#  leaky_re_lu_60 (LeakyReLU)     (None, 5, 128)       0           ['batch_normalization_48[0][0]']
#
#  conv1d_55 (Conv1D)             (None, 8, 256)       65536       ['leaky_re_lu_47[0][0]']
#
#  conv1d_70 (Conv1D)             (None, 5, 128)       49152       ['leaky_re_lu_60[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 256)      1024        ['conv1d_55[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 5, 128)      512         ['conv1d_70[0][0]']
#  ormalization)
#
#  leaky_re_lu_48 (LeakyReLU)     (None, 8, 256)       0           ['batch_normalization_39[0][0]']
#
#  leaky_re_lu_61 (LeakyReLU)     (None, 5, 128)       0           ['batch_normalization_49[0][0]']
#
#  conv1d_56 (Conv1D)             (None, 8, 256)       196608      ['leaky_re_lu_48[0][0]']
#
#  conv1d_71 (Conv1D)             (None, 5, 128)       16384       ['leaky_re_lu_61[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 8, 256)      1024        ['conv1d_56[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 5, 128)      512         ['conv1d_71[0][0]']
#  ormalization)
#
#  conv1d_68 (Conv1D)             (None, 5, 128)       384         ['design_in[0][0]']
#
#  leaky_re_lu_49 (LeakyReLU)     (None, 8, 256)       0           ['batch_normalization_40[0][0]']
#
#  add_20 (Add)                   (None, 5, 128)       0           ['batch_normalization_50[0][0]',
#                                                                   'conv1d_68[0][0]']
#
#  conv1d_57 (Conv1D)             (None, 8, 256)       65536       ['leaky_re_lu_49[0][0]']
#
#  leaky_re_lu_62 (LeakyReLU)     (None, 5, 128)       0           ['add_20[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 8, 256)      1024        ['conv1d_57[0][0]']
#  ormalization)
#
#  conv1d_72 (Conv1D)             (None, 5, 128)       16384       ['leaky_re_lu_62[0][0]']
#
#  add_16 (Add)                   (None, 8, 256)       0           ['batch_normalization_41[0][0]',
#                                                                   'leaky_re_lu_47[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 5, 128)      512         ['conv1d_72[0][0]']
#  ormalization)
#
#  leaky_re_lu_50 (LeakyReLU)     (None, 8, 256)       0           ['add_16[0][0]']
#
#  leaky_re_lu_63 (LeakyReLU)     (None, 5, 128)       0           ['batch_normalization_51[0][0]']
#
#  conv1d_58 (Conv1D)             (None, 8, 256)       65536       ['leaky_re_lu_50[0][0]']
#
#  conv1d_73 (Conv1D)             (None, 5, 128)       49152       ['leaky_re_lu_63[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 256)      1024        ['conv1d_58[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 5, 128)      512         ['conv1d_73[0][0]']
#  ormalization)
#
#  leaky_re_lu_51 (LeakyReLU)     (None, 8, 256)       0           ['batch_normalization_42[0][0]']
#
#  leaky_re_lu_64 (LeakyReLU)     (None, 5, 128)       0           ['batch_normalization_52[0][0]']
#
#  conv1d_59 (Conv1D)             (None, 8, 256)       196608      ['leaky_re_lu_51[0][0]']
#
#  conv1d_74 (Conv1D)             (None, 5, 128)       16384       ['leaky_re_lu_64[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 256)      1024        ['conv1d_59[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 5, 128)      512         ['conv1d_74[0][0]']
#  ormalization)
#
#  leaky_re_lu_52 (LeakyReLU)     (None, 8, 256)       0           ['batch_normalization_43[0][0]']
#
#  add_21 (Add)                   (None, 5, 128)       0           ['batch_normalization_53[0][0]',
#                                                                   'leaky_re_lu_62[0][0]']
#
#  conv1d_60 (Conv1D)             (None, 8, 256)       65536       ['leaky_re_lu_52[0][0]']
#
#  leaky_re_lu_65 (LeakyReLU)     (None, 5, 128)       0           ['add_21[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 8, 256)      1024        ['conv1d_60[0][0]']
#  ormalization)
#
#  conv1d_75 (Conv1D)             (None, 5, 128)       16384       ['leaky_re_lu_65[0][0]']
#
#  add_17 (Add)                   (None, 8, 256)       0           ['batch_normalization_44[0][0]',
#                                                                   'leaky_re_lu_50[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 5, 128)      512         ['conv1d_75[0][0]']
#  ormalization)
#
#  leaky_re_lu_53 (LeakyReLU)     (None, 8, 256)       0           ['add_17[0][0]']
#
#  leaky_re_lu_66 (LeakyReLU)     (None, 5, 128)       0           ['batch_normalization_54[0][0]']
#
#  conv1d_61 (Conv1D)             (None, 8, 256)       65536       ['leaky_re_lu_53[0][0]']
#
#  conv1d_76 (Conv1D)             (None, 5, 128)       49152       ['leaky_re_lu_66[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 256)      1024        ['conv1d_61[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 5, 128)      512         ['conv1d_76[0][0]']
#  ormalization)
#
#  leaky_re_lu_54 (LeakyReLU)     (None, 8, 256)       0           ['batch_normalization_45[0][0]']
#
#  leaky_re_lu_67 (LeakyReLU)     (None, 5, 128)       0           ['batch_normalization_55[0][0]']
#
#  conv1d_62 (Conv1D)             (None, 8, 256)       196608      ['leaky_re_lu_54[0][0]']
#
#  conv1d_77 (Conv1D)             (None, 5, 128)       16384       ['leaky_re_lu_67[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 8, 256)      1024        ['conv1d_62[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 5, 128)      512         ['conv1d_77[0][0]']
#  ormalization)
#
#  leaky_re_lu_55 (LeakyReLU)     (None, 8, 256)       0           ['batch_normalization_46[0][0]']
#
#  add_22 (Add)                   (None, 5, 128)       0           ['batch_normalization_56[0][0]',
#                                                                   'leaky_re_lu_65[0][0]']
#
#  conv1d_63 (Conv1D)             (None, 8, 256)       65536       ['leaky_re_lu_55[0][0]']
#
#  leaky_re_lu_68 (LeakyReLU)     (None, 5, 128)       0           ['add_22[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 8, 256)      1024        ['conv1d_63[0][0]']
#  ormalization)
#
#  conv1d_78 (Conv1D)             (None, 5, 128)       16384       ['leaky_re_lu_68[0][0]']
#
#  add_18 (Add)                   (None, 8, 256)       0           ['batch_normalization_47[0][0]',
#                                                                   'leaky_re_lu_53[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 5, 128)      512         ['conv1d_78[0][0]']
#  ormalization)
#
#  leaky_re_lu_56 (LeakyReLU)     (None, 8, 256)       0           ['add_18[0][0]']
#
#  leaky_re_lu_69 (LeakyReLU)     (None, 5, 128)       0           ['batch_normalization_57[0][0]']
#
#  conv1d_65 (Conv1D)             (None, 8, 256)       65792       ['leaky_re_lu_56[0][0]']
#
#  conv1d_79 (Conv1D)             (None, 5, 128)       49152       ['leaky_re_lu_69[0][0]']
#
#  leaky_re_lu_57 (LeakyReLU)     (None, 8, 256)       0           ['conv1d_65[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 5, 128)      512         ['conv1d_79[0][0]']
#  ormalization)
#
#  conv1d_66 (Conv1D)             (None, 4, 256)       196864      ['leaky_re_lu_57[0][0]']
#
#  leaky_re_lu_70 (LeakyReLU)     (None, 5, 128)       0           ['batch_normalization_58[0][0]']
#
#  leaky_re_lu_58 (LeakyReLU)     (None, 4, 256)       0           ['conv1d_66[0][0]']
#
#  conv1d_80 (Conv1D)             (None, 5, 128)       16384       ['leaky_re_lu_70[0][0]']
#
#  conv1d_67 (Conv1D)             (None, 4, 256)       65792       ['leaky_re_lu_58[0][0]']
#
#  conv1d_64 (Conv1D)             (None, 4, 256)       65792       ['leaky_re_lu_56[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 5, 128)      512         ['conv1d_80[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 4, 256)       0           ['conv1d_67[0][0]',
#                                                                   'conv1d_64[0][0]']
#
#  add_23 (Add)                   (None, 5, 128)       0           ['batch_normalization_59[0][0]',
#                                                                   'leaky_re_lu_68[0][0]']
#
#  leaky_re_lu_59 (LeakyReLU)     (None, 4, 256)       0           ['add_19[0][0]']
#
#  leaky_re_lu_71 (LeakyReLU)     (None, 5, 128)       0           ['add_23[0][0]']
#
#  flatten (Flatten)              (None, 1024)         0           ['leaky_re_lu_59[0][0]']
#
#  flatten_1 (Flatten)            (None, 640)          0           ['leaky_re_lu_71[0][0]']
#
#  concatenate (Concatenate)      (None, 1664)         0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense (Dense)                  (None, 256)          426240      ['concatenate[0][0]']
#
#  leaky_re_lu_72 (LeakyReLU)     (None, 256)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 2)            514         ['leaky_re_lu_72[0][0]']
#
#  dense_2 (Dense)                (None, 2)            514         ['leaky_re_lu_72[0][0]']
#
#  sampling_rng (SamplingRNG)     (None, 2)            0           ['dense_1[0][0]',
#                                                                   'dense_2[0][0]']
#
# ==================================================================================================
# Total params: 3,032,868
# Trainable params: 3,018,276
# Non-trainable params: 14,592
# __________________________________________________________________________________________________

# %% [markdown]
# ## define the decoder
#
# The second stage of the cVAE, and the actual inverse model after training, is the decoder.  It takes as input the condition (target spectrum) and a latent vector `z`. During training multiple design solutions for a given target spectrum will be mapped on different latent vectors `z` so that the latent space can be used to distinguish different solutions.

# %%
# condition_target_spec_input
latent_in = keras.Input(shape=(latent_dim,), name='latent_in')

# spectrum path
x = condition_target_spec_input
x = resblock_sequence_down(x, N_filter=32, N_blocks=N_blocks)   # 64 --> 32
x = resblock_sequence_down(x, N_filter=64, N_blocks=N_blocks)   # 32 --> 16
x = resblock_sequence_down(x, N_filter=128, N_blocks=N_blocks)  # 16 --> 8
x = resblock_sequence_down(x, N_filter=256, N_blocks=N_blocks)  # 8 --> 4
x_spec = keras.layers.Flatten()(x)

# merge with latent
x = keras.layers.Concatenate()([x_spec, latent_in])

# geometry generator path
x = keras.layers.Dense(5*128)(x)
x = keras.layers.Reshape((5, 128))(x)
x = resblock_sequence_id(x, N_filter=128, N_blocks=N_blocks)

# output: number of  channels from design
out_design = keras.layers.Conv1D(
    filters=x_train.shape[-1], kernel_size=1, name='design_out')(x)


decoder = keras.Model(
    [latent_in, condition_target_spec_input], 
    out_design, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  condition_in (InputLayer)      [(None, 64, 1)]      0           []
#
#  conv1d_82 (Conv1D)             (None, 64, 32)       32          ['condition_in[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 64, 32)      128         ['conv1d_82[0][0]']
#  ormalization)
#
#  leaky_re_lu_73 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_60[0][0]']
#
#  conv1d_83 (Conv1D)             (None, 64, 32)       3072        ['leaky_re_lu_73[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 64, 32)      128         ['conv1d_83[0][0]']
#  ormalization)
#
#  leaky_re_lu_74 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_61[0][0]']
#
#  conv1d_84 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_74[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 64, 32)      128         ['conv1d_84[0][0]']
#  ormalization)
#
#  conv1d_81 (Conv1D)             (None, 64, 32)       64          ['condition_in[0][0]']
#
#  add_24 (Add)                   (None, 64, 32)       0           ['batch_normalization_62[0][0]',
#                                                                   'conv1d_81[0][0]']
#
#  leaky_re_lu_75 (LeakyReLU)     (None, 64, 32)       0           ['add_24[0][0]']
#
#  conv1d_85 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_75[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 64, 32)      128         ['conv1d_85[0][0]']
#  ormalization)
#
#  leaky_re_lu_76 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_63[0][0]']
#
#  conv1d_86 (Conv1D)             (None, 64, 32)       3072        ['leaky_re_lu_76[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 64, 32)      128         ['conv1d_86[0][0]']
#  ormalization)
#
#  leaky_re_lu_77 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_64[0][0]']
#
#  conv1d_87 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_77[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 64, 32)      128         ['conv1d_87[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 64, 32)       0           ['batch_normalization_65[0][0]',
#                                                                   'leaky_re_lu_75[0][0]']
#
#  leaky_re_lu_78 (LeakyReLU)     (None, 64, 32)       0           ['add_25[0][0]']
#
#  conv1d_88 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_78[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 64, 32)      128         ['conv1d_88[0][0]']
#  ormalization)
#
#  leaky_re_lu_79 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_66[0][0]']
#
#  conv1d_89 (Conv1D)             (None, 64, 32)       3072        ['leaky_re_lu_79[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 64, 32)      128         ['conv1d_89[0][0]']
#  ormalization)
#
#  leaky_re_lu_80 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_67[0][0]']
#
#  conv1d_90 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_80[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 64, 32)      128         ['conv1d_90[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 64, 32)       0           ['batch_normalization_68[0][0]',
#                                                                   'leaky_re_lu_78[0][0]']
#
#  leaky_re_lu_81 (LeakyReLU)     (None, 64, 32)       0           ['add_26[0][0]']
#
#  conv1d_91 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_81[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 64, 32)      128         ['conv1d_91[0][0]']
#  ormalization)
#
#  leaky_re_lu_82 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_69[0][0]']
#
#  conv1d_92 (Conv1D)             (None, 64, 32)       3072        ['leaky_re_lu_82[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 64, 32)      128         ['conv1d_92[0][0]']
#  ormalization)
#
#  leaky_re_lu_83 (LeakyReLU)     (None, 64, 32)       0           ['batch_normalization_70[0][0]']
#
#  conv1d_93 (Conv1D)             (None, 64, 32)       1024        ['leaky_re_lu_83[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 64, 32)      128         ['conv1d_93[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 64, 32)       0           ['batch_normalization_71[0][0]',
#                                                                   'leaky_re_lu_81[0][0]']
#
#  leaky_re_lu_84 (LeakyReLU)     (None, 64, 32)       0           ['add_27[0][0]']
#
#  conv1d_95 (Conv1D)             (None, 64, 32)       1056        ['leaky_re_lu_84[0][0]']
#
#  leaky_re_lu_85 (LeakyReLU)     (None, 64, 32)       0           ['conv1d_95[0][0]']
#
#  conv1d_96 (Conv1D)             (None, 32, 32)       3104        ['leaky_re_lu_85[0][0]']
#
#  leaky_re_lu_86 (LeakyReLU)     (None, 32, 32)       0           ['conv1d_96[0][0]']
#
#  conv1d_97 (Conv1D)             (None, 32, 32)       1056        ['leaky_re_lu_86[0][0]']
#
#  conv1d_94 (Conv1D)             (None, 32, 32)       1056        ['leaky_re_lu_84[0][0]']
#
#  add_28 (Add)                   (None, 32, 32)       0           ['conv1d_97[0][0]',
#                                                                   'conv1d_94[0][0]']
#
#  leaky_re_lu_87 (LeakyReLU)     (None, 32, 32)       0           ['add_28[0][0]']
#
#  conv1d_99 (Conv1D)             (None, 32, 64)       2048        ['leaky_re_lu_87[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 32, 64)      256         ['conv1d_99[0][0]']
#  ormalization)
#
#  leaky_re_lu_88 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_72[0][0]']
#
#  conv1d_100 (Conv1D)            (None, 32, 64)       12288       ['leaky_re_lu_88[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 32, 64)      256         ['conv1d_100[0][0]']
#  ormalization)
#
#  leaky_re_lu_89 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_73[0][0]']
#
#  conv1d_101 (Conv1D)            (None, 32, 64)       4096        ['leaky_re_lu_89[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 32, 64)      256         ['conv1d_101[0][0]']
#  ormalization)
#
#  conv1d_98 (Conv1D)             (None, 32, 64)       2112        ['leaky_re_lu_87[0][0]']
#
#  add_29 (Add)                   (None, 32, 64)       0           ['batch_normalization_74[0][0]',
#                                                                   'conv1d_98[0][0]']
#
#  leaky_re_lu_90 (LeakyReLU)     (None, 32, 64)       0           ['add_29[0][0]']
#
#  conv1d_102 (Conv1D)            (None, 32, 64)       4096        ['leaky_re_lu_90[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 32, 64)      256         ['conv1d_102[0][0]']
#  ormalization)
#
#  leaky_re_lu_91 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_75[0][0]']
#
#  conv1d_103 (Conv1D)            (None, 32, 64)       12288       ['leaky_re_lu_91[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 32, 64)      256         ['conv1d_103[0][0]']
#  ormalization)
#
#  leaky_re_lu_92 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_76[0][0]']
#
#  conv1d_104 (Conv1D)            (None, 32, 64)       4096        ['leaky_re_lu_92[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 32, 64)      256         ['conv1d_104[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 32, 64)       0           ['batch_normalization_77[0][0]',
#                                                                   'leaky_re_lu_90[0][0]']
#
#  leaky_re_lu_93 (LeakyReLU)     (None, 32, 64)       0           ['add_30[0][0]']
#
#  conv1d_105 (Conv1D)            (None, 32, 64)       4096        ['leaky_re_lu_93[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 32, 64)      256         ['conv1d_105[0][0]']
#  ormalization)
#
#  leaky_re_lu_94 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_78[0][0]']
#
#  conv1d_106 (Conv1D)            (None, 32, 64)       12288       ['leaky_re_lu_94[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 32, 64)      256         ['conv1d_106[0][0]']
#  ormalization)
#
#  leaky_re_lu_95 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_79[0][0]']
#
#  conv1d_107 (Conv1D)            (None, 32, 64)       4096        ['leaky_re_lu_95[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 32, 64)      256         ['conv1d_107[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 32, 64)       0           ['batch_normalization_80[0][0]',
#                                                                   'leaky_re_lu_93[0][0]']
#
#  leaky_re_lu_96 (LeakyReLU)     (None, 32, 64)       0           ['add_31[0][0]']
#
#  conv1d_108 (Conv1D)            (None, 32, 64)       4096        ['leaky_re_lu_96[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 32, 64)      256         ['conv1d_108[0][0]']
#  ormalization)
#
#  leaky_re_lu_97 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_81[0][0]']
#
#  conv1d_109 (Conv1D)            (None, 32, 64)       12288       ['leaky_re_lu_97[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 32, 64)      256         ['conv1d_109[0][0]']
#  ormalization)
#
#  leaky_re_lu_98 (LeakyReLU)     (None, 32, 64)       0           ['batch_normalization_82[0][0]']
#
#  conv1d_110 (Conv1D)            (None, 32, 64)       4096        ['leaky_re_lu_98[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 32, 64)      256         ['conv1d_110[0][0]']
#  ormalization)
#
#  add_32 (Add)                   (None, 32, 64)       0           ['batch_normalization_83[0][0]',
#                                                                   'leaky_re_lu_96[0][0]']
#
#  leaky_re_lu_99 (LeakyReLU)     (None, 32, 64)       0           ['add_32[0][0]']
#
#  conv1d_112 (Conv1D)            (None, 32, 64)       4160        ['leaky_re_lu_99[0][0]']
#
#  leaky_re_lu_100 (LeakyReLU)    (None, 32, 64)       0           ['conv1d_112[0][0]']
#
#  conv1d_113 (Conv1D)            (None, 16, 64)       12352       ['leaky_re_lu_100[0][0]']
#
#  leaky_re_lu_101 (LeakyReLU)    (None, 16, 64)       0           ['conv1d_113[0][0]']
#
#  conv1d_114 (Conv1D)            (None, 16, 64)       4160        ['leaky_re_lu_101[0][0]']
#
#  conv1d_111 (Conv1D)            (None, 16, 64)       4160        ['leaky_re_lu_99[0][0]']
#
#  add_33 (Add)                   (None, 16, 64)       0           ['conv1d_114[0][0]',
#                                                                   'conv1d_111[0][0]']
#
#  leaky_re_lu_102 (LeakyReLU)    (None, 16, 64)       0           ['add_33[0][0]']
#
#  conv1d_116 (Conv1D)            (None, 16, 128)      8192        ['leaky_re_lu_102[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 16, 128)     512         ['conv1d_116[0][0]']
#  ormalization)
#
#  leaky_re_lu_103 (LeakyReLU)    (None, 16, 128)      0           ['batch_normalization_84[0][0]']
#
#  conv1d_117 (Conv1D)            (None, 16, 128)      49152       ['leaky_re_lu_103[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 16, 128)     512         ['conv1d_117[0][0]']
#  ormalization)
#
#  leaky_re_lu_104 (LeakyReLU)    (None, 16, 128)      0           ['batch_normalization_85[0][0]']
#
#  conv1d_118 (Conv1D)            (None, 16, 128)      16384       ['leaky_re_lu_104[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 16, 128)     512         ['conv1d_118[0][0]']
#  ormalization)
#
#  conv1d_115 (Conv1D)            (None, 16, 128)      8320        ['leaky_re_lu_102[0][0]']
#
#  add_34 (Add)                   (None, 16, 128)      0           ['batch_normalization_86[0][0]',
#                                                                   'conv1d_115[0][0]']
#
#  leaky_re_lu_105 (LeakyReLU)    (None, 16, 128)      0           ['add_34[0][0]']
#
#  conv1d_119 (Conv1D)            (None, 16, 128)      16384       ['leaky_re_lu_105[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 16, 128)     512         ['conv1d_119[0][0]']
#  ormalization)
#
#  leaky_re_lu_106 (LeakyReLU)    (None, 16, 128)      0           ['batch_normalization_87[0][0]']
#
#  conv1d_120 (Conv1D)            (None, 16, 128)      49152       ['leaky_re_lu_106[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 16, 128)     512         ['conv1d_120[0][0]']
#  ormalization)
#
#  leaky_re_lu_107 (LeakyReLU)    (None, 16, 128)      0           ['batch_normalization_88[0][0]']
#
#  conv1d_121 (Conv1D)            (None, 16, 128)      16384       ['leaky_re_lu_107[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 16, 128)     512         ['conv1d_121[0][0]']
#  ormalization)
#
#  add_35 (Add)                   (None, 16, 128)      0           ['batch_normalization_89[0][0]',
#                                                                   'leaky_re_lu_105[0][0]']
#
#  leaky_re_lu_108 (LeakyReLU)    (None, 16, 128)      0           ['add_35[0][0]']
#
#  conv1d_122 (Conv1D)            (None, 16, 128)      16384       ['leaky_re_lu_108[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 16, 128)     512         ['conv1d_122[0][0]']
#  ormalization)
#
#  leaky_re_lu_109 (LeakyReLU)    (None, 16, 128)      0           ['batch_normalization_90[0][0]']
#
#  conv1d_123 (Conv1D)            (None, 16, 128)      49152       ['leaky_re_lu_109[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 16, 128)     512         ['conv1d_123[0][0]']
#  ormalization)
#
#  leaky_re_lu_110 (LeakyReLU)    (None, 16, 128)      0           ['batch_normalization_91[0][0]']
#
#  conv1d_124 (Conv1D)            (None, 16, 128)      16384       ['leaky_re_lu_110[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 16, 128)     512         ['conv1d_124[0][0]']
#  ormalization)
#
#  add_36 (Add)                   (None, 16, 128)      0           ['batch_normalization_92[0][0]',
#                                                                   'leaky_re_lu_108[0][0]']
#
#  leaky_re_lu_111 (LeakyReLU)    (None, 16, 128)      0           ['add_36[0][0]']
#
#  conv1d_125 (Conv1D)            (None, 16, 128)      16384       ['leaky_re_lu_111[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 16, 128)     512         ['conv1d_125[0][0]']
#  ormalization)
#
#  leaky_re_lu_112 (LeakyReLU)    (None, 16, 128)      0           ['batch_normalization_93[0][0]']
#
#  conv1d_126 (Conv1D)            (None, 16, 128)      49152       ['leaky_re_lu_112[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 16, 128)     512         ['conv1d_126[0][0]']
#  ormalization)
#
#  leaky_re_lu_113 (LeakyReLU)    (None, 16, 128)      0           ['batch_normalization_94[0][0]']
#
#  conv1d_127 (Conv1D)            (None, 16, 128)      16384       ['leaky_re_lu_113[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 16, 128)     512         ['conv1d_127[0][0]']
#  ormalization)
#
#  add_37 (Add)                   (None, 16, 128)      0           ['batch_normalization_95[0][0]',
#                                                                   'leaky_re_lu_111[0][0]']
#
#  leaky_re_lu_114 (LeakyReLU)    (None, 16, 128)      0           ['add_37[0][0]']
#
#  conv1d_129 (Conv1D)            (None, 16, 128)      16512       ['leaky_re_lu_114[0][0]']
#
#  leaky_re_lu_115 (LeakyReLU)    (None, 16, 128)      0           ['conv1d_129[0][0]']
#
#  conv1d_130 (Conv1D)            (None, 8, 128)       49280       ['leaky_re_lu_115[0][0]']
#
#  leaky_re_lu_116 (LeakyReLU)    (None, 8, 128)       0           ['conv1d_130[0][0]']
#
#  conv1d_131 (Conv1D)            (None, 8, 128)       16512       ['leaky_re_lu_116[0][0]']
#
#  conv1d_128 (Conv1D)            (None, 8, 128)       16512       ['leaky_re_lu_114[0][0]']
#
#  add_38 (Add)                   (None, 8, 128)       0           ['conv1d_131[0][0]',
#                                                                   'conv1d_128[0][0]']
#
#  leaky_re_lu_117 (LeakyReLU)    (None, 8, 128)       0           ['add_38[0][0]']
#
#  conv1d_133 (Conv1D)            (None, 8, 256)       32768       ['leaky_re_lu_117[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 8, 256)      1024        ['conv1d_133[0][0]']
#  ormalization)
#
#  leaky_re_lu_118 (LeakyReLU)    (None, 8, 256)       0           ['batch_normalization_96[0][0]']
#
#  conv1d_134 (Conv1D)            (None, 8, 256)       196608      ['leaky_re_lu_118[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 8, 256)      1024        ['conv1d_134[0][0]']
#  ormalization)
#
#  leaky_re_lu_119 (LeakyReLU)    (None, 8, 256)       0           ['batch_normalization_97[0][0]']
#
#  conv1d_135 (Conv1D)            (None, 8, 256)       65536       ['leaky_re_lu_119[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 8, 256)      1024        ['conv1d_135[0][0]']
#  ormalization)
#
#  conv1d_132 (Conv1D)            (None, 8, 256)       33024       ['leaky_re_lu_117[0][0]']
#
#  add_39 (Add)                   (None, 8, 256)       0           ['batch_normalization_98[0][0]',
#                                                                   'conv1d_132[0][0]']
#
#  leaky_re_lu_120 (LeakyReLU)    (None, 8, 256)       0           ['add_39[0][0]']
#
#  conv1d_136 (Conv1D)            (None, 8, 256)       65536       ['leaky_re_lu_120[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 8, 256)      1024        ['conv1d_136[0][0]']
#  ormalization)
#
#  leaky_re_lu_121 (LeakyReLU)    (None, 8, 256)       0           ['batch_normalization_99[0][0]']
#
#  conv1d_137 (Conv1D)            (None, 8, 256)       196608      ['leaky_re_lu_121[0][0]']
#
#  batch_normalization_100 (Batch  (None, 8, 256)      1024        ['conv1d_137[0][0]']
#  Normalization)
#
#  leaky_re_lu_122 (LeakyReLU)    (None, 8, 256)       0           ['batch_normalization_100[0][0]']
#
#  conv1d_138 (Conv1D)            (None, 8, 256)       65536       ['leaky_re_lu_122[0][0]']
#
#  batch_normalization_101 (Batch  (None, 8, 256)      1024        ['conv1d_138[0][0]']
#  Normalization)
#
#  add_40 (Add)                   (None, 8, 256)       0           ['batch_normalization_101[0][0]',
#                                                                   'leaky_re_lu_120[0][0]']
#
#  leaky_re_lu_123 (LeakyReLU)    (None, 8, 256)       0           ['add_40[0][0]']
#
#  conv1d_139 (Conv1D)            (None, 8, 256)       65536       ['leaky_re_lu_123[0][0]']
#
#  batch_normalization_102 (Batch  (None, 8, 256)      1024        ['conv1d_139[0][0]']
#  Normalization)
#
#  leaky_re_lu_124 (LeakyReLU)    (None, 8, 256)       0           ['batch_normalization_102[0][0]']
#
#  conv1d_140 (Conv1D)            (None, 8, 256)       196608      ['leaky_re_lu_124[0][0]']
#
#  batch_normalization_103 (Batch  (None, 8, 256)      1024        ['conv1d_140[0][0]']
#  Normalization)
#
#  leaky_re_lu_125 (LeakyReLU)    (None, 8, 256)       0           ['batch_normalization_103[0][0]']
#
#  conv1d_141 (Conv1D)            (None, 8, 256)       65536       ['leaky_re_lu_125[0][0]']
#
#  batch_normalization_104 (Batch  (None, 8, 256)      1024        ['conv1d_141[0][0]']
#  Normalization)
#
#  add_41 (Add)                   (None, 8, 256)       0           ['batch_normalization_104[0][0]',
#                                                                   'leaky_re_lu_123[0][0]']
#
#  leaky_re_lu_126 (LeakyReLU)    (None, 8, 256)       0           ['add_41[0][0]']
#
#  conv1d_142 (Conv1D)            (None, 8, 256)       65536       ['leaky_re_lu_126[0][0]']
#
#  batch_normalization_105 (Batch  (None, 8, 256)      1024        ['conv1d_142[0][0]']
#  Normalization)
#
#  leaky_re_lu_127 (LeakyReLU)    (None, 8, 256)       0           ['batch_normalization_105[0][0]']
#
#  conv1d_143 (Conv1D)            (None, 8, 256)       196608      ['leaky_re_lu_127[0][0]']
#
#  batch_normalization_106 (Batch  (None, 8, 256)      1024        ['conv1d_143[0][0]']
#  Normalization)
#
#  leaky_re_lu_128 (LeakyReLU)    (None, 8, 256)       0           ['batch_normalization_106[0][0]']
#
#  conv1d_144 (Conv1D)            (None, 8, 256)       65536       ['leaky_re_lu_128[0][0]']
#
#  batch_normalization_107 (Batch  (None, 8, 256)      1024        ['conv1d_144[0][0]']
#  Normalization)
#
#  add_42 (Add)                   (None, 8, 256)       0           ['batch_normalization_107[0][0]',
#                                                                   'leaky_re_lu_126[0][0]']
#
#  leaky_re_lu_129 (LeakyReLU)    (None, 8, 256)       0           ['add_42[0][0]']
#
#  conv1d_146 (Conv1D)            (None, 8, 256)       65792       ['leaky_re_lu_129[0][0]']
#
#  leaky_re_lu_130 (LeakyReLU)    (None, 8, 256)       0           ['conv1d_146[0][0]']
#
#  conv1d_147 (Conv1D)            (None, 4, 256)       196864      ['leaky_re_lu_130[0][0]']
#
#  leaky_re_lu_131 (LeakyReLU)    (None, 4, 256)       0           ['conv1d_147[0][0]']
#
#  conv1d_148 (Conv1D)            (None, 4, 256)       65792       ['leaky_re_lu_131[0][0]']
#
#  conv1d_145 (Conv1D)            (None, 4, 256)       65792       ['leaky_re_lu_129[0][0]']
#
#  add_43 (Add)                   (None, 4, 256)       0           ['conv1d_148[0][0]',
#                                                                   'conv1d_145[0][0]']
#
#  leaky_re_lu_132 (LeakyReLU)    (None, 4, 256)       0           ['add_43[0][0]']
#
#  flatten_2 (Flatten)            (None, 1024)         0           ['leaky_re_lu_132[0][0]']
#
#  latent_in (InputLayer)         [(None, 2)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 1026)         0           ['flatten_2[0][0]',
#                                                                   'latent_in[0][0]']
#
#  dense_3 (Dense)                (None, 640)          657280      ['concatenate_1[0][0]']
#
#  reshape (Reshape)              (None, 5, 128)       0           ['dense_3[0][0]']
#
#  conv1d_149 (Conv1D)            (None, 5, 128)       16384       ['reshape[0][0]']
#
#  batch_normalization_108 (Batch  (None, 5, 128)      512         ['conv1d_149[0][0]']
#  Normalization)
#
#  leaky_re_lu_133 (LeakyReLU)    (None, 5, 128)       0           ['batch_normalization_108[0][0]']
#
#  conv1d_150 (Conv1D)            (None, 5, 128)       49152       ['leaky_re_lu_133[0][0]']
#
#  batch_normalization_109 (Batch  (None, 5, 128)      512         ['conv1d_150[0][0]']
#  Normalization)
#
#  leaky_re_lu_134 (LeakyReLU)    (None, 5, 128)       0           ['batch_normalization_109[0][0]']
#
#  conv1d_151 (Conv1D)            (None, 5, 128)       16384       ['leaky_re_lu_134[0][0]']
#
#  batch_normalization_110 (Batch  (None, 5, 128)      512         ['conv1d_151[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 5, 128)       0           ['batch_normalization_110[0][0]',
#                                                                   'reshape[0][0]']
#
#  leaky_re_lu_135 (LeakyReLU)    (None, 5, 128)       0           ['add_44[0][0]']
#
#  conv1d_152 (Conv1D)            (None, 5, 128)       16384       ['leaky_re_lu_135[0][0]']
#
#  batch_normalization_111 (Batch  (None, 5, 128)      512         ['conv1d_152[0][0]']
#  Normalization)
#
#  leaky_re_lu_136 (LeakyReLU)    (None, 5, 128)       0           ['batch_normalization_111[0][0]']
#
#  conv1d_153 (Conv1D)            (None, 5, 128)       49152       ['leaky_re_lu_136[0][0]']
#
#  batch_normalization_112 (Batch  (None, 5, 128)      512         ['conv1d_153[0][0]']
#  Normalization)
#
#  leaky_re_lu_137 (LeakyReLU)    (None, 5, 128)       0           ['batch_normalization_112[0][0]']
#
#  conv1d_154 (Conv1D)            (None, 5, 128)       16384       ['leaky_re_lu_137[0][0]']
#
#  batch_normalization_113 (Batch  (None, 5, 128)      512         ['conv1d_154[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 5, 128)       0           ['batch_normalization_113[0][0]',
#                                                                   'leaky_re_lu_135[0][0]']
#
#  leaky_re_lu_138 (LeakyReLU)    (None, 5, 128)       0           ['add_45[0][0]']
#
#  conv1d_155 (Conv1D)            (None, 5, 128)       16384       ['leaky_re_lu_138[0][0]']
#
#  batch_normalization_114 (Batch  (None, 5, 128)      512         ['conv1d_155[0][0]']
#  Normalization)
#
#  leaky_re_lu_139 (LeakyReLU)    (None, 5, 128)       0           ['batch_normalization_114[0][0]']
#
#  conv1d_156 (Conv1D)            (None, 5, 128)       49152       ['leaky_re_lu_139[0][0]']
#
#  batch_normalization_115 (Batch  (None, 5, 128)      512         ['conv1d_156[0][0]']
#  Normalization)
#
#  leaky_re_lu_140 (LeakyReLU)    (None, 5, 128)       0           ['batch_normalization_115[0][0]']
#
#  conv1d_157 (Conv1D)            (None, 5, 128)       16384       ['leaky_re_lu_140[0][0]']
#
#  batch_normalization_116 (Batch  (None, 5, 128)      512         ['conv1d_157[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 5, 128)       0           ['batch_normalization_116[0][0]',
#                                                                   'leaky_re_lu_138[0][0]']
#
#  leaky_re_lu_141 (LeakyReLU)    (None, 5, 128)       0           ['add_46[0][0]']
#
#  conv1d_158 (Conv1D)            (None, 5, 128)       16384       ['leaky_re_lu_141[0][0]']
#
#  batch_normalization_117 (Batch  (None, 5, 128)      512         ['conv1d_158[0][0]']
#  Normalization)
#
#  leaky_re_lu_142 (LeakyReLU)    (None, 5, 128)       0           ['batch_normalization_117[0][0]']
#
#  conv1d_159 (Conv1D)            (None, 5, 128)       49152       ['leaky_re_lu_142[0][0]']
#
#  batch_normalization_118 (Batch  (None, 5, 128)      512         ['conv1d_159[0][0]']
#  Normalization)
#
#  leaky_re_lu_143 (LeakyReLU)    (None, 5, 128)       0           ['batch_normalization_118[0][0]']
#
#  conv1d_160 (Conv1D)            (None, 5, 128)       16384       ['leaky_re_lu_143[0][0]']
#
#  batch_normalization_119 (Batch  (None, 5, 128)      512         ['conv1d_160[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 5, 128)       0           ['batch_normalization_119[0][0]',
#                                                                   'leaky_re_lu_141[0][0]']
#
#  leaky_re_lu_144 (LeakyReLU)    (None, 5, 128)       0           ['add_47[0][0]']
#
#  design_out (Conv1D)            (None, 5, 2)         258         ['leaky_re_lu_144[0][0]']
#
# ==================================================================================================
# Total params: 3,278,882
# Trainable params: 3,264,290
# Non-trainable params: 14,592
# __________________________________________________________________________________________________

# %% [markdown]
# ## Define the full cVAE

# %%
z_mean_out, z_var_log_out, z_rnd_out = encoder([design_in, condition_target_spec_input])
design_pred = decoder([z_rnd_out, condition_target_spec_input])   # use randomized latent

cVAE = keras.Model([design_in, condition_target_spec_input], design_pred, name="cVAE")
cVAE.summary()
# Out:
# Model: "cVAE"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  design_in (InputLayer)         [(None, 5, 2)]       0           []
#
#  condition_in (InputLayer)      [(None, 64, 1)]      0           []
#
#  encoder (Functional)           [(None, 2),          3032868     ['design_in[0][0]',
#                                  (None, 2),                       'condition_in[0][0]']
#                                  (None, 2)]
#
#  decoder (Functional)           (None, 5, 2)         3278882     ['encoder[0][2]',
#                                                                   'condition_in[0][0]']
#
# ==================================================================================================
# Total params: 6,311,750
# Trainable params: 6,282,566
# Non-trainable params: 29,184
# __________________________________________________________________________________________________

# %% [markdown]
# ## cVAE losses: reconstruction and KL
#
# In order to regularize the latent space, we need to add a Kullback-Leibler divergence (KL) loss in addition to the MSE reconstruction loss. Adding custom loss functions in keras can be done via `model.add_loss`. We also add according metrics, those are only used for the status messages during training.
# Finally we can compile and train the model with the optimizer (`AdamW`).

# %%
input_dim = np.product(x_train.shape[1:])
latent_dim = np.product(z.shape[1:])
beta = 0.001   # weight of KL loss. If too high, reconstruction will suffer.


# --- add multiple losses to the model
# reconstruction loss
reconstruction_loss = keras.losses.mse(
    keras.backend.flatten(design_in), 
    keras.backend.flatten(design_pred))
cVAE.add_loss(reconstruction_loss)
cVAE.add_metric(reconstruction_loss, name='reconstr_loss', aggregation='mean')

# KL loss
kl_loss = keras.backend.sum(
    1 + z_var_log_out - keras.backend.square(z_mean_out) - keras.backend.exp(z_var_log_out), axis=-1)
kl_loss = beta * keras.backend.mean(-0.5 / latent_dim * kl_loss)
cVAE.add_loss(kl_loss)
cVAE.add_metric(kl_loss, name='kl_loss', aggregation='mean')

# %% [markdown]
# ## Train the cVAE end-to-end
#
# In contrast to the 2-stage training of the Tandem, the cVAE is trained end-to-end in a single run. Note that we have now two inputs for the full cVAE model: designs and spectra, the model output are the reconstructed designs, which are compared to the input designs via MSE loss.
#
# After training, for inverse design we will use only the decoder part.

# %%
# compile the model
optimizer = keras.optimizers.AdamW(learning_rate=0.0002)
cVAE.compile(optimizer=optimizer)

## ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=1/3, patience=5, verbose=1)

# fit the model with BN --> increasing batchsize schdedule
hist = None  # global history after BS incrase
for i in range(4):  # 4x50 epochs, doubling batchsize
    _h = cVAE.fit(x=[x_train, y_train], y=[x_train],
                  validation_split=.2,
                  batch_size=16 * 2**i, epochs=50,
                  callbacks = [reduce_lr])
    if hist is None:
        hist = _h
    else:
        for k in hist.history:
            hist.history[k] = np.concatenate([hist.history[k], _h.history[k]])

# plot loss
plt.figure()
plt.plot(hist.history['loss'], label='loss')
plt.plot(hist.history['val_loss'], label='val_loss')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 2023-07-03 13:47:32.093267: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-03 13:47:34.195549: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-07-03 13:47:34.240783: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f118a82c340 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-03 13:47:34.240801: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2023-07-03 13:47:34.244037: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-03 13:47:34.364560: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2375/2375 [==============================] - 321s 107ms/step - loss: 0.7728 - reconstr_loss: 0.7587 - kl_loss: 0.0141 - val_loss: 0.5913 - val_reconstr_loss: 0.5783 - val_kl_loss: 0.0130 - lr: 2.0000e-04
# Epoch 2/50
# 2375/2375 [==============================] - 255s 107ms/step - loss: 0.5429 - reconstr_loss: 0.5324 - kl_loss: 0.0105 - val_loss: 0.4931 - val_reconstr_loss: 0.4829 - val_kl_loss: 0.0102 - lr: 2.0000e-04
# Epoch 3/50
# 2375/2375 [==============================] - 255s 107ms/step - loss: 0.4637 - reconstr_loss: 0.4547 - kl_loss: 0.0090 - val_loss: 0.4388 - val_reconstr_loss: 0.4299 - val_kl_loss: 0.0089 - lr: 2.0000e-04
# Epoch 4/50
# 2375/2375 [==============================] - 275s 116ms/step - loss: 0.4169 - reconstr_loss: 0.4087 - kl_loss: 0.0081 - val_loss: 0.3819 - val_reconstr_loss: 0.3737 - val_kl_loss: 0.0082 - lr: 2.0000e-04
# Epoch 5/50
# 2375/2375 [==============================] - 272s 115ms/step - loss: 0.3834 - reconstr_loss: 0.3758 - kl_loss: 0.0076 - val_loss: 0.3844 - val_reconstr_loss: 0.3767 - val_kl_loss: 0.0078 - lr: 2.0000e-04
# Epoch 6/50
# 2375/2375 [==============================] - 271s 114ms/step - loss: 0.3579 - reconstr_loss: 0.3506 - kl_loss: 0.0073 - val_loss: 0.3543 - val_reconstr_loss: 0.3476 - val_kl_loss: 0.0067 - lr: 2.0000e-04
# Epoch 7/50
# 2375/2375 [==============================] - 271s 114ms/step - loss: 0.3371 - reconstr_loss: 0.3301 - kl_loss: 0.0070 - val_loss: 0.3224 - val_reconstr_loss: 0.3162 - val_kl_loss: 0.0062 - lr: 2.0000e-04
# Epoch 8/50
# 2375/2375 [==============================] - 255s 107ms/step - loss: 0.3221 - reconstr_loss: 0.3152 - kl_loss: 0.0069 - val_loss: 0.3090 - val_reconstr_loss: 0.3026 - val_kl_loss: 0.0064 - lr: 2.0000e-04
# Epoch 9/50
# 2375/2375 [==============================] - 253s 106ms/step - loss: 0.3070 - reconstr_loss: 0.3002 - kl_loss: 0.0068 - val_loss: 0.3109 - val_reconstr_loss: 0.3045 - val_kl_loss: 0.0064 - lr: 2.0000e-04
# Epoch 10/50
# 2375/2375 [==============================] - 253s 106ms/step - loss: 0.2969 - reconstr_loss: 0.2902 - kl_loss: 0.0067 - val_loss: 0.2960 - val_reconstr_loss: 0.2894 - val_kl_loss: 0.0066 - lr: 2.0000e-04
# Epoch 11/50
# 2375/2375 [==============================] - 257s 108ms/step - loss: 0.2822 - reconstr_loss: 0.2757 - kl_loss: 0.0065 - val_loss: 0.3004 - val_reconstr_loss: 0.2934 - val_kl_loss: 0.0070 - lr: 2.0000e-04
# Epoch 12/50
# 2375/2375 [==============================] - 258s 109ms/step - loss: 0.2803 - reconstr_loss: 0.2736 - kl_loss: 0.0067 - val_loss: 0.2863 - val_reconstr_loss: 0.2798 - val_kl_loss: 0.0066 - lr: 2.0000e-04
# Epoch 13/50
# 2375/2375 [==============================] - 253s 106ms/step - loss: 0.2645 - reconstr_loss: 0.2578 - kl_loss: 0.0067 - val_loss: 0.2604 - val_reconstr_loss: 0.2538 - val_kl_loss: 0.0066 - lr: 2.0000e-04
# Epoch 14/50
# 2375/2375 [==============================] - 255s 107ms/step - loss: 0.2619 - reconstr_loss: 0.2555 - kl_loss: 0.0064 - val_loss: 0.2529 - val_reconstr_loss: 0.2464 - val_kl_loss: 0.0065 - lr: 2.0000e-04
# Epoch 15/50
# 2375/2375 [==============================] - 250s 105ms/step - loss: 0.2580 - reconstr_loss: 0.2517 - kl_loss: 0.0063 - val_loss: 0.2482 - val_reconstr_loss: 0.2413 - val_kl_loss: 0.0068 - lr: 2.0000e-04
# Epoch 16/50
# 2375/2375 [==============================] - 257s 108ms/step - loss: 0.2496 - reconstr_loss: 0.2433 - kl_loss: 0.0063 - val_loss: 0.2546 - val_reconstr_loss: 0.2484 - val_kl_loss: 0.0062 - lr: 2.0000e-04
# Epoch 17/50
# 2375/2375 [==============================] - 242s 102ms/step - loss: 0.2449 - reconstr_loss: 0.2386 - kl_loss: 0.0063 - val_loss: 0.2555 - val_reconstr_loss: 0.2486 - val_kl_loss: 0.0068 - lr: 2.0000e-04
# Epoch 18/50
# 2375/2375 [==============================] - 242s 102ms/step - loss: 0.2419 - reconstr_loss: 0.2358 - kl_loss: 0.0061 - val_loss: 0.2470 - val_reconstr_loss: 0.2412 - val_kl_loss: 0.0059 - lr: 2.0000e-04
# Epoch 19/50
# 2375/2375 [==============================] - 239s 101ms/step - loss: 0.2370 - reconstr_loss: 0.2308 - kl_loss: 0.0062 - val_loss: 0.2453 - val_reconstr_loss: 0.2388 - val_kl_loss: 0.0064 - lr: 2.0000e-04
# Epoch 20/50
# 2375/2375 [==============================] - 235s 99ms/step - loss: 0.2347 - reconstr_loss: 0.2285 - kl_loss: 0.0061 - val_loss: 0.2729 - val_reconstr_loss: 0.2669 - val_kl_loss: 0.0060 - lr: 2.0000e-04
# Epoch 21/50
# 2375/2375 [==============================] - 236s 99ms/step - loss: 0.2386 - reconstr_loss: 0.2326 - kl_loss: 0.0060 - val_loss: 0.2376 - val_reconstr_loss: 0.2315 - val_kl_loss: 0.0061 - lr: 2.0000e-04
# Epoch 22/50
# 2375/2375 [==============================] - 241s 101ms/step - loss: 0.2263 - reconstr_loss: 0.2203 - kl_loss: 0.0060 - val_loss: 0.2272 - val_reconstr_loss: 0.2210 - val_kl_loss: 0.0062 - lr: 2.0000e-04
# Epoch 23/50
# 2375/2375 [==============================] - 239s 100ms/step - loss: 0.2356 - reconstr_loss: 0.2297 - kl_loss: 0.0060 - val_loss: 0.2675 - val_reconstr_loss: 0.2617 - val_kl_loss: 0.0058 - lr: 2.0000e-04
# Epoch 24/50
# 2375/2375 [==============================] - 245s 103ms/step - loss: 0.2403 - reconstr_loss: 0.2344 - kl_loss: 0.0059 - val_loss: 0.2406 - val_reconstr_loss: 0.2345 - val_kl_loss: 0.0061 - lr: 2.0000e-04
# Epoch 25/50
# 2375/2375 [==============================] - 233s 98ms/step - loss: 0.2288 - reconstr_loss: 0.2229 - kl_loss: 0.0060 - val_loss: 0.2498 - val_reconstr_loss: 0.2441 - val_kl_loss: 0.0057 - lr: 2.0000e-04
# Epoch 26/50
# 2375/2375 [==============================] - 235s 99ms/step - loss: 0.2170 - reconstr_loss: 0.2112 - kl_loss: 0.0059 - val_loss: 0.2414 - val_reconstr_loss: 0.2355 - val_kl_loss: 0.0059 - lr: 2.0000e-04
# Epoch 27/50
# 2375/2375 [==============================] - 237s 100ms/step - loss: 0.2126 - reconstr_loss: 0.2065 - kl_loss: 0.0061 - val_loss: 0.2182 - val_reconstr_loss: 0.2122 - val_kl_loss: 0.0060 - lr: 2.0000e-04
# Epoch 28/50
# 2375/2375 [==============================] - 249s 105ms/step - loss: 0.2115 - reconstr_loss: 0.2057 - kl_loss: 0.0058 - val_loss: 0.2237 - val_reconstr_loss: 0.2180 - val_kl_loss: 0.0056 - lr: 2.0000e-04
# Epoch 29/50
# 2375/2375 [==============================] - 251s 106ms/step - loss: 0.2129 - reconstr_loss: 0.2072 - kl_loss: 0.0057 - val_loss: 0.2160 - val_reconstr_loss: 0.2104 - val_kl_loss: 0.0057 - lr: 2.0000e-04
# Epoch 30/50
# 2375/2375 [==============================] - 246s 104ms/step - loss: 0.2027 - reconstr_loss: 0.1968 - kl_loss: 0.0059 - val_loss: 0.2021 - val_reconstr_loss: 0.1964 - val_kl_loss: 0.0058 - lr: 2.0000e-04
# Epoch 31/50
# 2375/2375 [==============================] - 245s 103ms/step - loss: 0.2025 - reconstr_loss: 0.1968 - kl_loss: 0.0058 - val_loss: 0.2389 - val_reconstr_loss: 0.2327 - val_kl_loss: 0.0062 - lr: 2.0000e-04
# Epoch 32/50
# 2375/2375 [==============================] - 246s 103ms/step - loss: 0.1964 - reconstr_loss: 0.1905 - kl_loss: 0.0059 - val_loss: 0.2071 - val_reconstr_loss: 0.2017 - val_kl_loss: 0.0055 - lr: 2.0000e-04
# Epoch 33/50
# 2375/2375 [==============================] - 248s 104ms/step - loss: 0.1947 - reconstr_loss: 0.1891 - kl_loss: 0.0057 - val_loss: 0.2153 - val_reconstr_loss: 0.2094 - val_kl_loss: 0.0059 - lr: 2.0000e-04
# Epoch 34/50
# 2375/2375 [==============================] - 248s 105ms/step - loss: 0.1901 - reconstr_loss: 0.1842 - kl_loss: 0.0059 - val_loss: 0.2104 - val_reconstr_loss: 0.2048 - val_kl_loss: 0.0056 - lr: 2.0000e-04
# Epoch 35/50
# 2375/2375 [==============================] - ETA: 0s - loss: 0.2004 - reconstr_loss: 0.1947 - kl_loss: 0.0057
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.6666664982525e-05.
# 2375/2375 [==============================] - 267s 113ms/step - loss: 0.2004 - reconstr_loss: 0.1947 - kl_loss: 0.0057 - val_loss: 0.2195 - val_reconstr_loss: 0.2140 - val_kl_loss: 0.0055 - lr: 2.0000e-04
# Epoch 36/50
# 2375/2375 [==============================] - 256s 108ms/step - loss: 0.1575 - reconstr_loss: 0.1521 - kl_loss: 0.0054 - val_loss: 0.1829 - val_reconstr_loss: 0.1775 - val_kl_loss: 0.0054 - lr: 6.6667e-05
# Epoch 37/50
# 2375/2375 [==============================] - 265s 112ms/step - loss: 0.1471 - reconstr_loss: 0.1419 - kl_loss: 0.0052 - val_loss: 0.1736 - val_reconstr_loss: 0.1684 - val_kl_loss: 0.0052 - lr: 6.6667e-05
# Epoch 38/50
# 2375/2375 [==============================] - 270s 114ms/step - loss: 0.1403 - reconstr_loss: 0.1351 - kl_loss: 0.0051 - val_loss: 0.1735 - val_reconstr_loss: 0.1685 - val_kl_loss: 0.0050 - lr: 6.6667e-05
# Epoch 39/50
# 2375/2375 [==============================] - 257s 108ms/step - loss: 0.1376 - reconstr_loss: 0.1326 - kl_loss: 0.0050 - val_loss: 0.1722 - val_reconstr_loss: 0.1671 - val_kl_loss: 0.0051 - lr: 6.6667e-05
# Epoch 40/50
# 2375/2375 [==============================] - 271s 114ms/step - loss: 0.1371 - reconstr_loss: 0.1322 - kl_loss: 0.0049 - val_loss: 0.1752 - val_reconstr_loss: 0.1704 - val_kl_loss: 0.0048 - lr: 6.6667e-05
# Epoch 41/50
# 2375/2375 [==============================] - 256s 108ms/step - loss: 0.1353 - reconstr_loss: 0.1305 - kl_loss: 0.0049 - val_loss: 0.1743 - val_reconstr_loss: 0.1694 - val_kl_loss: 0.0049 - lr: 6.6667e-05
# Epoch 42/50
# 2375/2375 [==============================] - 260s 110ms/step - loss: 0.1344 - reconstr_loss: 0.1295 - kl_loss: 0.0049 - val_loss: 0.1748 - val_reconstr_loss: 0.1700 - val_kl_loss: 0.0048 - lr: 6.6667e-05
# Epoch 43/50
# 2375/2375 [==============================] - 265s 112ms/step - loss: 0.1361 - reconstr_loss: 0.1313 - kl_loss: 0.0048 - val_loss: 0.1698 - val_reconstr_loss: 0.1651 - val_kl_loss: 0.0047 - lr: 6.6667e-05
# Epoch 44/50
# 2375/2375 [==============================] - 267s 113ms/step - loss: 0.1346 - reconstr_loss: 0.1299 - kl_loss: 0.0047 - val_loss: 0.1684 - val_reconstr_loss: 0.1637 - val_kl_loss: 0.0047 - lr: 6.6667e-05
# Epoch 45/50
#  660/2375 [=======>......................] - ETA: 3:05 - loss: 0.1242 - reconstr_loss: 0.1195 - kl_loss: 0.0047

# %% [markdown]
# ## save the cVAE sub-models

# %%
cVAE.save('models/inversenet_cVAE_full.h5')
encoder.save('models/inversenet_cVAE_enc.h5')
decoder.save('models/inversenet_cVAE_dec.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## Demo: reload a saved model
#
# A previously saved model can be reloaded in keras as follows:

# %%
decoder = keras.models.load_model('models/inversenet_cVAE_dec.h5')
# Out:
# 2023-06-28 10:43:27.918892: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 10:43:27.919121: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 10:43:27.919240: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 10:43:27.919532: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 10:43:27.919658: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 10:43:27.919772: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 10:43:27.919932: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 10:43:27.920051: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 10:43:27.920140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9331 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:21:00.0, compute capability: 8.9
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Some simple benchmarking

# %%
# plot statistics
z_sample = np.random.normal(size=(500, 2))
#z_sample = np.zeros(shape=(500, 2))
y_sample = y_test[np.random.choice(len(y_test), len(z_sample), replace=False)]
decoder_in = [z_sample, y_sample]
designs_predict = decoder.predict(decoder_in, verbose=0)
y_resim = helper.calc_R_for_network_designs(designs_predict, scaler_mat, scaler_thick)

helper.plot_benchmark_R_stat(y_resim, y_sample)
# Out:
# pymoosh: calculating R for 500 samples...
# 500it [00:04, 107.45it/s]

# %%
# take a random, known, single spectrum as target
i_test = np.random.randint(len(y_test))

# evaluate 9 positions in latent space
z_sample = np.array([[i, i] for i in np.linspace(-1, 1, 9) ])

# predict and simulate via pymoosh
y_sample = y_test[len(z_sample)*[i_test]]
decoder_in = [z_sample, y_sample]
designs_predict = decoder.predict(decoder_in, verbose=0)
y_resim = helper.calc_R_for_network_designs(
    designs_predict, scaler_mat, scaler_thick)

# plot results
helper.plot_benchmark_R_samples(y_resim, y_sample, N_plot=(3, 3),
                                random_order=False, plot_design=True,
                                y_designs=designs_predict,
                                scaler_mat=scaler_mat, scaler_thick=scaler_thick,
                                labels=['simulation', 'design target'])
# Out:
# pymoosh: calculating R for 9 samples...
# 9it [00:00, 106.89it/s]
