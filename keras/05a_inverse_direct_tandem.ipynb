# %% [markdown]
# # Direct inverse design: Tandem network
#
# ## Import modules

# %%
import pickle
import os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

import helper

# Dynamic GPU memory allocation: For local prototyping, don't block GPU
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.compat.v1.Session(config=config)
# Out:
# 2023-06-21 15:52:36.520171: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 15:52:37.073288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-21 15:52:38.078523: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:38.096933: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:38.097130: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:38.570853: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:38.571026: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:38.571152: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:38.571255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 17015 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:21:00.0, compute capability: 8.9

# %% [markdown]
# ## load the training data

# %%
data_path = 'datasets/dataset1_random.h5'

# load data and scalers
x_train, x_test, y_train, y_test = helper.load_reflection_spectra_data(data_path)
scaler_mat, scaler_thick = pickle.load(
    open('{}_scalers.pkl'.format(os.path.splitext(data_path)[0]), 'rb'))

# %% [markdown]
# ## load pre-trained forward model and freeze weights
#
# The forward model is pre-trained, we do not want it to be modified (further trained) in the inverse net training. If the forward model was subject to further training, the inputs would loose their meaning as design parameters.
# We therefore need to set the forward model as not trainable.
#
# *Note*: If a full model is set to `trainable = False`, the model needs to be compiled, for it to have an effect. Setting the model to `trainable = False` after compilation, this does not have any effect. To avoid recompilation, every single layer can be set to `trainable=False` in a loop through the model layers, which works also on compiled models without re-compilation.

# %%
model_path = 'models/fwd_model_resnet.h5'

# load pretrained forward model
fwd_model = keras.models.load_model(model_path)
fwd_model.trainable = False

# quick test if model works
y_predict = fwd_model.predict(x_test, verbose=0)
helper.plot_benchmark_R_model(y_predict, y_test, N_plot=(2,3))
# Out:
# 2023-06-21 15:52:39.042637: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:39.042835: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:39.042951: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:39.043183: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:39.043312: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:39.043427: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:39.043579: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:39.043697: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-21 15:52:39.043786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 17015 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:21:00.0, compute capability: 8.9
# 2023-06-21 15:52:41.134034: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-21 15:52:41.802069: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %% [markdown]
# ### Inverse resnet model
#
# *Note*, instead of `MaxPooling`, we here use `strides=2` to reduce the output dimension of a convolution by a factor of 2. In the up-sampling case (see forward model), strides can also be used with transpose convolutions to increase the output dimension. However the latter often leads to artifacts in the upsampled outputs, therefore for a robust first try dedicated `UpSampling` layers are preferred.
#
# In the down-sampling case, strides usually don't induce artifacts and are computationally cheaper as well as are more flexible (they are trainable), in contrast to `MaxPooling`.

# %%
keras.backend.clear_session()
N_blocks = 4     # Nr of resblocks between upsamplings


# spectrum in
target_spec_input = keras.layers.Input(shape=y_train.shape[1:])
x = target_spec_input

for i in range(N_blocks):
    x = helper.residual_block(x, 32, kernel_size=3, strides=1)
# use strides=2 for downsampling. 64 --> 32
x = helper.residual_block(x, 32, kernel_size=3, strides=2)

for i in range(N_blocks):
    x = helper.residual_block(x, 64, kernel_size=3, strides=1)
x = helper.residual_block(x, 64, kernel_size=3, strides=2)   # 32 --> 16

for i in range(N_blocks):
    x = helper.residual_block(x, 128, kernel_size=3, strides=1)
x = helper.residual_block(x, 128, kernel_size=3, strides=2)   # 16 --> 8

x = keras.layers.ZeroPadding1D((1, 1))(x)             # 8 --> 1 + 8 + 1 --> 10
for i in range(N_blocks):
    x = helper.residual_block(x, 256, kernel_size=3, strides=1)
x = helper.residual_block(x, 256, kernel_size=3, strides=2)  # 10 --> 5

# design out
design_output = keras.layers.Conv1D(
    filters=2, kernel_size=1, padding='same')(x)

inverse_model = keras.models.Model(
    inputs=target_spec_input, outputs=design_output, name='resnet_inverse_model')
inverse_model.summary()
# Out:
# Model: "resnet_inverse_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 1)]      0           []
#
#  conv1d_1 (Conv1D)              (None, 64, 32)       64          ['input_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 64, 32)       0           ['conv1d_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 64, 32)       3104        ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 64, 32)       0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 64, 32)       1056        ['leaky_re_lu_1[0][0]']
#
#  conv1d (Conv1D)                (None, 64, 32)       64          ['input_1[0][0]']
#
#  add (Add)                      (None, 64, 32)       0           ['conv1d_3[0][0]',
#                                                                   'conv1d[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 64, 32)       0           ['add[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 64, 32)       1056        ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 64, 32)       0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 64, 32)       3104        ['leaky_re_lu_3[0][0]']
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 64, 32)       0           ['conv1d_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 64, 32)       1056        ['leaky_re_lu_4[0][0]']
#
#  add_1 (Add)                    (None, 64, 32)       0           ['conv1d_6[0][0]',
#                                                                   'leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 64, 32)       0           ['add_1[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 64, 32)       1056        ['leaky_re_lu_5[0][0]']
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 64, 32)       0           ['conv1d_7[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 64, 32)       3104        ['leaky_re_lu_6[0][0]']
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 64, 32)       0           ['conv1d_8[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 64, 32)       1056        ['leaky_re_lu_7[0][0]']
#
#  add_2 (Add)                    (None, 64, 32)       0           ['conv1d_9[0][0]',
#                                                                   'leaky_re_lu_5[0][0]']
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 64, 32)       0           ['add_2[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 64, 32)       1056        ['leaky_re_lu_8[0][0]']
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 64, 32)       0           ['conv1d_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 64, 32)       3104        ['leaky_re_lu_9[0][0]']
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 64, 32)       0           ['conv1d_11[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 64, 32)       1056        ['leaky_re_lu_10[0][0]']
#
#  add_3 (Add)                    (None, 64, 32)       0           ['conv1d_12[0][0]',
#                                                                   'leaky_re_lu_8[0][0]']
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 64, 32)       0           ['add_3[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 64, 32)       1056        ['leaky_re_lu_11[0][0]']
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 64, 32)       0           ['conv1d_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 32, 32)       3104        ['leaky_re_lu_12[0][0]']
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 32, 32)       0           ['conv1d_15[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 32, 32)       1056        ['leaky_re_lu_13[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 32, 32)       1056        ['leaky_re_lu_11[0][0]']
#
#  add_4 (Add)                    (None, 32, 32)       0           ['conv1d_16[0][0]',
#                                                                   'conv1d_13[0][0]']
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 32, 32)       0           ['add_4[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 32, 64)       2112        ['leaky_re_lu_14[0][0]']
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_18[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 32, 64)       12352       ['leaky_re_lu_15[0][0]']
#
#  leaky_re_lu_16 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_19[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_16[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 32, 64)       2112        ['leaky_re_lu_14[0][0]']
#
#  add_5 (Add)                    (None, 32, 64)       0           ['conv1d_20[0][0]',
#                                                                   'conv1d_17[0][0]']
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 32, 64)       0           ['add_5[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_17[0][0]']
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_21[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 32, 64)       12352       ['leaky_re_lu_18[0][0]']
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_22[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_19[0][0]']
#
#  add_6 (Add)                    (None, 32, 64)       0           ['conv1d_23[0][0]',
#                                                                   'leaky_re_lu_17[0][0]']
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 32, 64)       0           ['add_6[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_20[0][0]']
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_24[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 32, 64)       12352       ['leaky_re_lu_21[0][0]']
#
#  leaky_re_lu_22 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_25[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_22[0][0]']
#
#  add_7 (Add)                    (None, 32, 64)       0           ['conv1d_26[0][0]',
#                                                                   'leaky_re_lu_20[0][0]']
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 32, 64)       0           ['add_7[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_23[0][0]']
#
#  leaky_re_lu_24 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_27[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 32, 64)       12352       ['leaky_re_lu_24[0][0]']
#
#  leaky_re_lu_25 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_28[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_25[0][0]']
#
#  add_8 (Add)                    (None, 32, 64)       0           ['conv1d_29[0][0]',
#                                                                   'leaky_re_lu_23[0][0]']
#
#  leaky_re_lu_26 (LeakyReLU)     (None, 32, 64)       0           ['add_8[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 32, 64)       4160        ['leaky_re_lu_26[0][0]']
#
#  leaky_re_lu_27 (LeakyReLU)     (None, 32, 64)       0           ['conv1d_31[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 16, 64)       12352       ['leaky_re_lu_27[0][0]']
#
#  leaky_re_lu_28 (LeakyReLU)     (None, 16, 64)       0           ['conv1d_32[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 16, 64)       4160        ['leaky_re_lu_28[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 16, 64)       4160        ['leaky_re_lu_26[0][0]']
#
#  add_9 (Add)                    (None, 16, 64)       0           ['conv1d_33[0][0]',
#                                                                   'conv1d_30[0][0]']
#
#  leaky_re_lu_29 (LeakyReLU)     (None, 16, 64)       0           ['add_9[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 16, 128)      8320        ['leaky_re_lu_29[0][0]']
#
#  leaky_re_lu_30 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_35[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 16, 128)      49280       ['leaky_re_lu_30[0][0]']
#
#  leaky_re_lu_31 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_36[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_31[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 16, 128)      8320        ['leaky_re_lu_29[0][0]']
#
#  add_10 (Add)                   (None, 16, 128)      0           ['conv1d_37[0][0]',
#                                                                   'conv1d_34[0][0]']
#
#  leaky_re_lu_32 (LeakyReLU)     (None, 16, 128)      0           ['add_10[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_32[0][0]']
#
#  leaky_re_lu_33 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_38[0][0]']
#
#  conv1d_39 (Conv1D)             (None, 16, 128)      49280       ['leaky_re_lu_33[0][0]']
#
#  leaky_re_lu_34 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_39[0][0]']
#
#  conv1d_40 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_34[0][0]']
#
#  add_11 (Add)                   (None, 16, 128)      0           ['conv1d_40[0][0]',
#                                                                   'leaky_re_lu_32[0][0]']
#
#  leaky_re_lu_35 (LeakyReLU)     (None, 16, 128)      0           ['add_11[0][0]']
#
#  conv1d_41 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_35[0][0]']
#
#  leaky_re_lu_36 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_41[0][0]']
#
#  conv1d_42 (Conv1D)             (None, 16, 128)      49280       ['leaky_re_lu_36[0][0]']
#
#  leaky_re_lu_37 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_42[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_37[0][0]']
#
#  add_12 (Add)                   (None, 16, 128)      0           ['conv1d_43[0][0]',
#                                                                   'leaky_re_lu_35[0][0]']
#
#  leaky_re_lu_38 (LeakyReLU)     (None, 16, 128)      0           ['add_12[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_38[0][0]']
#
#  leaky_re_lu_39 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_44[0][0]']
#
#  conv1d_45 (Conv1D)             (None, 16, 128)      49280       ['leaky_re_lu_39[0][0]']
#
#  leaky_re_lu_40 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_45[0][0]']
#
#  conv1d_46 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_40[0][0]']
#
#  add_13 (Add)                   (None, 16, 128)      0           ['conv1d_46[0][0]',
#                                                                   'leaky_re_lu_38[0][0]']
#
#  leaky_re_lu_41 (LeakyReLU)     (None, 16, 128)      0           ['add_13[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 16, 128)      16512       ['leaky_re_lu_41[0][0]']
#
#  leaky_re_lu_42 (LeakyReLU)     (None, 16, 128)      0           ['conv1d_48[0][0]']
#
#  conv1d_49 (Conv1D)             (None, 8, 128)       49280       ['leaky_re_lu_42[0][0]']
#
#  leaky_re_lu_43 (LeakyReLU)     (None, 8, 128)       0           ['conv1d_49[0][0]']
#
#  conv1d_50 (Conv1D)             (None, 8, 128)       16512       ['leaky_re_lu_43[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 8, 128)       16512       ['leaky_re_lu_41[0][0]']
#
#  add_14 (Add)                   (None, 8, 128)       0           ['conv1d_50[0][0]',
#                                                                   'conv1d_47[0][0]']
#
#  leaky_re_lu_44 (LeakyReLU)     (None, 8, 128)       0           ['add_14[0][0]']
#
#  zero_padding1d (ZeroPadding1D)  (None, 10, 128)     0           ['leaky_re_lu_44[0][0]']
#
#  conv1d_52 (Conv1D)             (None, 10, 256)      33024       ['zero_padding1d[0][0]']
#
#  leaky_re_lu_45 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_52[0][0]']
#
#  conv1d_53 (Conv1D)             (None, 10, 256)      196864      ['leaky_re_lu_45[0][0]']
#
#  leaky_re_lu_46 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_53[0][0]']
#
#  conv1d_54 (Conv1D)             (None, 10, 256)      65792       ['leaky_re_lu_46[0][0]']
#
#  conv1d_51 (Conv1D)             (None, 10, 256)      33024       ['zero_padding1d[0][0]']
#
#  add_15 (Add)                   (None, 10, 256)      0           ['conv1d_54[0][0]',
#                                                                   'conv1d_51[0][0]']
#
#  leaky_re_lu_47 (LeakyReLU)     (None, 10, 256)      0           ['add_15[0][0]']
#
#  conv1d_55 (Conv1D)             (None, 10, 256)      65792       ['leaky_re_lu_47[0][0]']
#
#  leaky_re_lu_48 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_55[0][0]']
#
#  conv1d_56 (Conv1D)             (None, 10, 256)      196864      ['leaky_re_lu_48[0][0]']
#
#  leaky_re_lu_49 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_56[0][0]']
#
#  conv1d_57 (Conv1D)             (None, 10, 256)      65792       ['leaky_re_lu_49[0][0]']
#
#  add_16 (Add)                   (None, 10, 256)      0           ['conv1d_57[0][0]',
#                                                                   'leaky_re_lu_47[0][0]']
#
#  leaky_re_lu_50 (LeakyReLU)     (None, 10, 256)      0           ['add_16[0][0]']
#
#  conv1d_58 (Conv1D)             (None, 10, 256)      65792       ['leaky_re_lu_50[0][0]']
#
#  leaky_re_lu_51 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_58[0][0]']
#
#  conv1d_59 (Conv1D)             (None, 10, 256)      196864      ['leaky_re_lu_51[0][0]']
#
#  leaky_re_lu_52 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_59[0][0]']
#
#  conv1d_60 (Conv1D)             (None, 10, 256)      65792       ['leaky_re_lu_52[0][0]']
#
#  add_17 (Add)                   (None, 10, 256)      0           ['conv1d_60[0][0]',
#                                                                   'leaky_re_lu_50[0][0]']
#
#  leaky_re_lu_53 (LeakyReLU)     (None, 10, 256)      0           ['add_17[0][0]']
#
#  conv1d_61 (Conv1D)             (None, 10, 256)      65792       ['leaky_re_lu_53[0][0]']
#
#  leaky_re_lu_54 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_61[0][0]']
#
#  conv1d_62 (Conv1D)             (None, 10, 256)      196864      ['leaky_re_lu_54[0][0]']
#
#  leaky_re_lu_55 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_62[0][0]']
#
#  conv1d_63 (Conv1D)             (None, 10, 256)      65792       ['leaky_re_lu_55[0][0]']
#
#  add_18 (Add)                   (None, 10, 256)      0           ['conv1d_63[0][0]',
#                                                                   'leaky_re_lu_53[0][0]']
#
#  leaky_re_lu_56 (LeakyReLU)     (None, 10, 256)      0           ['add_18[0][0]']
#
#  conv1d_65 (Conv1D)             (None, 10, 256)      65792       ['leaky_re_lu_56[0][0]']
#
#  leaky_re_lu_57 (LeakyReLU)     (None, 10, 256)      0           ['conv1d_65[0][0]']
#
#  conv1d_66 (Conv1D)             (None, 5, 256)       196864      ['leaky_re_lu_57[0][0]']
#
#  leaky_re_lu_58 (LeakyReLU)     (None, 5, 256)       0           ['conv1d_66[0][0]']
#
#  conv1d_67 (Conv1D)             (None, 5, 256)       65792       ['leaky_re_lu_58[0][0]']
#
#  conv1d_64 (Conv1D)             (None, 5, 256)       65792       ['leaky_re_lu_56[0][0]']
#
#  add_19 (Add)                   (None, 5, 256)       0           ['conv1d_67[0][0]',
#                                                                   'conv1d_64[0][0]']
#
#  leaky_re_lu_59 (LeakyReLU)     (None, 5, 256)       0           ['add_19[0][0]']
#
#  conv1d_68 (Conv1D)             (None, 5, 2)         514         ['leaky_re_lu_59[0][0]']
#
# ==================================================================================================
# Total params: 2,270,754
# Trainable params: 2,270,754
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Define the full tandem model
#
# Training the inverse model directly on the data does not work because of the problem's ill posed character. We therefore train it through the forward network.
# To this end we feed the inverse model (generator) output into the pre-trained forward model and create a new "tandem" model.
# Printing the model's summary we see that only about half of the parameters are trainable, confirming that we fixed the forward model's weights.

# %%
# inverse_model_model.compile(optimizer = keras.optimizers.Adam(learning_rate=0.001), loss='mse')

# get the inputs. alternatively we can re-use the layer as defined in the model above
tandem_input = inverse_model.inputs
inverse_output = inverse_model(tandem_input)
tandem_output = fwd_model(inverse_output)

tandem = keras.models.Model(inputs=tandem_input, outputs=tandem_output)

tandem.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 1)]           0
#
#  resnet_inverse_model (Funct  (None, 5, 2)             2270754
#  ional)
#
#  resnet_model (Functional)   (None, 64, 1)             1818337
#
# =================================================================
# Total params: 4,089,091
# Trainable params: 2,270,754
# Non-trainable params: 1,818,337
# _________________________________________________________________

# %% [markdown]
# ## Tandem training
#
# Now we compile the model with an optimizer (`AdamW`) and mean square error loss, we add callbacks and then run the training.
#
# ### Note on training data
#
# The full tandem model takes as input the design target spectrum and returns the predicted spectrum of the suggested geometry. Therefore we do not use the geometries for training anymore, but we use the spectra for both, in- and output.

# %%
# compile with optimizer and cost function
tandem.compile(optimizer=keras.optimizers.AdamW(learning_rate=0.001),
               loss='mse')

## ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=1/3, patience=5, verbose=1)

# callback for checkpoint saving
checkpoint_save = ModelCheckpoint(filepath='checkpoints/tandem/',
                                  monitor='val_loss', save_weights_only=True, save_best_only=True)

history = tandem.fit(x=y_train, y=y_train,
                     validation_split=.2,
                     batch_size=32, epochs=50,
                     callbacks = [reduce_lr, checkpoint_save])
# Out:
# Epoch 1/50
# 2023-06-21 15:52:54.115574: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f513ff11f90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-21 15:52:54.115607: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2023-06-21 15:52:54.118864: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-21 15:52:54.225527: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1188/1188 [==============================] - 83s 53ms/step - loss: 0.0124 - val_loss: 0.0037 - lr: 0.0010
# Epoch 2/50
# 1188/1188 [==============================] - 60s 51ms/step - loss: 0.0032 - val_loss: 0.0032 - lr: 0.0010
# Epoch 3/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 0.0025 - val_loss: 0.0025 - lr: 0.0010
# Epoch 4/50
# 1188/1188 [==============================] - 59s 49ms/step - loss: 0.0022 - val_loss: 0.0032 - lr: 0.0010
# Epoch 5/50
# 1188/1188 [==============================] - 60s 51ms/step - loss: 0.0022 - val_loss: 0.0018 - lr: 0.0010
# Epoch 6/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 0.0022 - val_loss: 0.0025 - lr: 0.0010
# Epoch 7/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 0.0020 - val_loss: 0.0022 - lr: 0.0010
# Epoch 8/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 0.0021 - val_loss: 0.0038 - lr: 0.0010
# Epoch 9/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 0.0020 - val_loss: 0.0021 - lr: 0.0010
# Epoch 10/50
# 1187/1188 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0003333333491658171.
# 1188/1188 [==============================] - 60s 51ms/step - loss: 0.0019 - val_loss: 0.0019 - lr: 0.0010
# Epoch 11/50
# 1188/1188 [==============================] - 61s 52ms/step - loss: 9.8684e-04 - val_loss: 0.0011 - lr: 3.3333e-04
# Epoch 12/50
# 1188/1188 [==============================] - 61s 51ms/step - loss: 0.0011 - val_loss: 0.0011 - lr: 3.3333e-04
# Epoch 13/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 0.0011 - val_loss: 8.1661e-04 - lr: 3.3333e-04
# Epoch 14/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 9.2662e-04 - val_loss: 8.7465e-04 - lr: 3.3333e-04
# Epoch 15/50
# 1188/1188 [==============================] - 59s 49ms/step - loss: 9.5250e-04 - val_loss: 8.4036e-04 - lr: 3.3333e-04
# Epoch 16/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 9.5256e-04 - val_loss: 8.2269e-04 - lr: 3.3333e-04
# Epoch 17/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 8.7152e-04 - val_loss: 7.4796e-04 - lr: 3.3333e-04
# Epoch 18/50
# 1187/1188 [============================>.] - ETA: 0s - loss: 8.2959e-04
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00011111111962236464.
# 1188/1188 [==============================] - 59s 50ms/step - loss: 8.2954e-04 - val_loss: 8.2531e-04 - lr: 3.3333e-04
# Epoch 19/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 6.2037e-04 - val_loss: 5.6692e-04 - lr: 1.1111e-04
# Epoch 20/50
# 1188/1188 [==============================] - 58s 49ms/step - loss: 5.9215e-04 - val_loss: 5.6969e-04 - lr: 1.1111e-04
# Epoch 21/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 5.7126e-04 - val_loss: 5.2354e-04 - lr: 1.1111e-04
# Epoch 22/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 5.4739e-04 - val_loss: 5.3899e-04 - lr: 1.1111e-04
# Epoch 23/50
# 1188/1188 [==============================] - 60s 51ms/step - loss: 5.6844e-04 - val_loss: 5.8141e-04 - lr: 1.1111e-04
# Epoch 24/50
# 1187/1188 [============================>.] - ETA: 0s - loss: 5.3444e-04
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.703703987412155e-05.
# 1188/1188 [==============================] - 60s 51ms/step - loss: 5.3438e-04 - val_loss: 5.0359e-04 - lr: 1.1111e-04
# Epoch 25/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 4.4006e-04 - val_loss: 4.4618e-04 - lr: 3.7037e-05
# Epoch 26/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 4.2723e-04 - val_loss: 4.6357e-04 - lr: 3.7037e-05
# Epoch 27/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 4.1067e-04 - val_loss: 4.5059e-04 - lr: 3.7037e-05
# Epoch 28/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 4.0846e-04 - val_loss: 4.1791e-04 - lr: 3.7037e-05
# Epoch 29/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 4.2082e-04 - val_loss: 4.2734e-04 - lr: 3.7037e-05
# Epoch 30/50
# 1188/1188 [==============================] - ETA: 0s - loss: 3.9664e-04
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.2345679958040515e-05.
# 1188/1188 [==============================] - 59s 50ms/step - loss: 3.9664e-04 - val_loss: 3.9848e-04 - lr: 3.7037e-05
# Epoch 31/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.5317e-04 - val_loss: 3.8591e-04 - lr: 1.2346e-05
# Epoch 32/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.4086e-04 - val_loss: 3.7208e-04 - lr: 1.2346e-05
# Epoch 33/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 3.4214e-04 - val_loss: 3.7481e-04 - lr: 1.2346e-05
# Epoch 34/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 3.4793e-04 - val_loss: 3.8255e-04 - lr: 1.2346e-05
# Epoch 35/50
# 1187/1188 [============================>.] - ETA: 0s - loss: 3.4260e-04
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.115226753735138e-06.
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.4261e-04 - val_loss: 3.7753e-04 - lr: 1.2346e-05
# Epoch 36/50
# 1188/1188 [==============================] - 60s 51ms/step - loss: 3.3355e-04 - val_loss: 3.6173e-04 - lr: 4.1152e-06
# Epoch 37/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.2435e-04 - val_loss: 3.5936e-04 - lr: 4.1152e-06
# Epoch 38/50
# 1188/1188 [==============================] - 59s 50ms/step - loss: 3.2096e-04 - val_loss: 3.6370e-04 - lr: 4.1152e-06
# Epoch 39/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.2205e-04 - val_loss: 3.5953e-04 - lr: 4.1152e-06
# Epoch 40/50
# 1188/1188 [==============================] - ETA: 0s - loss: 3.1925e-04
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.3717422007175628e-06.
# 1188/1188 [==============================] - 59s 50ms/step - loss: 3.1925e-04 - val_loss: 3.6488e-04 - lr: 4.1152e-06
# Epoch 41/50
# 1188/1188 [==============================] - 59s 49ms/step - loss: 3.1737e-04 - val_loss: 3.6121e-04 - lr: 1.3717e-06
# Epoch 42/50
# 1188/1188 [==============================] - 59s 49ms/step - loss: 3.1563e-04 - val_loss: 3.6079e-04 - lr: 1.3717e-06
# Epoch 43/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.1423e-04 - val_loss: 3.5926e-04 - lr: 1.3717e-06
# Epoch 44/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.1322e-04 - val_loss: 3.5800e-04 - lr: 1.3717e-06
# Epoch 45/50
# 1188/1188 [==============================] - ETA: 0s - loss: 3.1209e-04
# Epoch 45: ReduceLROnPlateau reducing learning rate to 4.572474002391876e-07.
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.1209e-04 - val_loss: 3.5841e-04 - lr: 1.3717e-06
# Epoch 46/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.1060e-04 - val_loss: 3.5620e-04 - lr: 4.5725e-07
# Epoch 47/50
# 1188/1188 [==============================] - 60s 51ms/step - loss: 3.0966e-04 - val_loss: 3.5603e-04 - lr: 4.5725e-07
# Epoch 48/50
# 1188/1188 [==============================] - 60s 51ms/step - loss: 3.0937e-04 - val_loss: 3.5639e-04 - lr: 4.5725e-07
# Epoch 49/50
# 1188/1188 [==============================] - 60s 50ms/step - loss: 3.0910e-04 - val_loss: 3.5547e-04 - lr: 4.5725e-07
# Epoch 50/50
# 1188/1188 [==============================] - ETA: 0s - loss: 3.0870e-04
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.524158032376969e-07.
# 1188/1188 [==============================] - 61s 51ms/step - loss: 3.0870e-04 - val_loss: 3.5526e-04 - lr: 4.5725e-07

# %% [markdown]
# ## save the models

# %%
tandem.save('models/inversenet_tandem_full.h5')
inverse_model.save('models/inversenet_tandem_generator.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ## plot loss convergence during training

# %%
# plot the learning convergence
plt.figure()
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.yscale('log')
plt.legend()
plt.show()

# %% [markdown]
# ## test inverse designs suggested by the tandem model
#
# We undertake following steps:
#
# - predict inverse designs for the test-set spectra
# - use the forward network to predict spectra of the inverse designs
# - use pymoosh to calculate the spectra of the inverse designs
# - plot samples and error statistics
#
# For the other inverse design notebooks, the recalculation of the R-spectra via pymoosh as it is done here, is available in a `helper` function `helper.calc_R_for_network_designs`

# %%
# predict designs and their R-spectra (via forward model)
designs_predict = inverse_model.predict(y_test, verbose=0)
y_predict = fwd_model.predict(designs_predict, verbose=0)

# scaler inverse transform: normalized datarange --> physical datarange
mat_physical = scaler_mat.inverse_transform(designs_predict[..., 0])
thick_physical = scaler_thick.inverse_transform(designs_predict[..., 1])

# pymoosh calculation of all designs
wavelengths = np.linspace(500, 1500, 64)
y_recalc = helper.batch_calc_R(thick_physical, mat_physical, wavelengths)

# plot statistics and samples
# helper.plot_benchmark_R_model(y_predict, y_test, labels=['fwd-net', 'design target'])
helper.plot_benchmark_R_model(y_recalc, y_test, labels=['pymoosh', 'design target'])
# Out:
# pymoosh: calculating R for 2500 samples...
# 2500it [00:23, 105.07it/s]
